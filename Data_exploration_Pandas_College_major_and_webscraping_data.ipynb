# %% [markdown]
# ## Data analysis on various university majors and their salaries at different points in their career

# %% [markdown]
# ### source:  we will begin with the 2008 dataset of the university majors collected from the website:
# ### https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors
#
# ### Later we will webscrape the 2023 data from this website:

# %%
import pandas as pd
import numpy as np
df =  pd.read_csv("salaries_by_college_major.csv")

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# 13                      Computer Science                 55900.0
# 14                          Construction                 53700.0
# 15                      Criminal Justice                 35000.0
# 16                                 Drama                 35900.0
# 17                             Economics                 50100.0
# 18                             Education                 34900.0
# 19                Electrical Engineering                 60900.0
# 20                               English                 38000.0
# 21                                  Film                 37900.0
# 22                               Finance                 47900.0
# 23                              Forestry                 39100.0
# 24                             Geography                 41200.0
# 25                               Geology                 43500.0
# 26                        Graphic Design                 35700.0
# 27            Health Care Administration                 38800.0
# 28                               History                 39200.0
# 29                 Hospitality & Tourism                 37800.0
# 30                Industrial Engineering                 57700.0
# 31           Information Technology (IT)                 49100.0
# 32                       Interior Design                 36100.0
# 33               International Relations                 40900.0
# 34                            Journalism                 35600.0
# 35  Management Information Systems (MIS)                 49200.0
# 36                             Marketing                 40800.0
# 37                                  Math                 45400.0
# 38                Mechanical Engineering                 57900.0
# 39                                 Music                 35900.0
# 40                               Nursing                 54200.0
# 41                             Nutrition                 39900.0
# 42                            Philosophy                 39900.0
# 43                   Physician Assistant                 74300.0
# 44                               Physics                 50300.0
# 45                     Political Science                 40800.0
# 46                            Psychology                 35900.0
# 47                              Religion                 34100.0
# 48                             Sociology                 36500.0
# 49                               Spanish                 34000.0
# 50                 Source: PayScale Inc.                     NaN
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                    77100.0                            42200.0
# 1                   101000.0                            64300.0
# 2                    71900.0                            36300.0
# 3                    61500.0                            33800.0
# 4                    76800.0                            50600.0
# 5                    64900.0                            28800.0
# 6                    64800.0                            36900.0
# 7                    72100.0                            38800.0
# 8                   107000.0                            71900.0
# 9                    79900.0                            45300.0
# 10                   90500.0                            63400.0
# 11                   70000.0                            37500.0
# 12                  105000.0                            66100.0
# 13                   95500.0                            56000.0
# 14                   88900.0                            56300.0
# 15                   56300.0                            32200.0
# 16                   56900.0                            36700.0
# 17                   98600.0                            50600.0
# 18                   52000.0                            29300.0
# 19                  103000.0                            69300.0
# 20                   64700.0                            33400.0
# 21                   68500.0                            33900.0
# 22                   88300.0                            47200.0
# 23                   62600.0                            41000.0
# 24                   65500.0                            40000.0
# 25                   79500.0                            45000.0
# 26                   59800.0                            36000.0
# 27                   60600.0                            34600.0
# 28                   71000.0                            37000.0
# 29                   57500.0                            35500.0
# 30                   94700.0                            57100.0
# 31                   74800.0                            44500.0
# 32                   53200.0                            35700.0
# 33                   80900.0                            38200.0
# 34                   66700.0                            38400.0
# 35                   82300.0                            45300.0
# 36                   79600.0                            42100.0
# 37                   92400.0                            45200.0
# 38                   93600.0                            63700.0
# 39                   55000.0                            26700.0
# 40                   67000.0                            47600.0
# 41                   55300.0                            33900.0
# 42                   81200.0                            35500.0
# 43                   91700.0                            66400.0
# 44                   97300.0                            56000.0
# 45                   78200.0                            41200.0
# 46                   60400.0                            31600.0
# 47                   52000.0                            29700.0
# 48                   58200.0                            30700.0
# 49                   53100.0                            31000.0
# 50                       NaN                                NaN
#
#     Mid-Career 90th Percentile Salary     Group
# 0                            152000.0  Business
# 1                            161000.0      STEM
# 2                            150000.0  Business
# 3                            138000.0      HASS
# 4                            136000.0  Business
# 5                            125000.0      HASS
# 6                            135000.0      STEM
# 7                            147000.0  Business
# 8                            194000.0      STEM
# 9                            148000.0      STEM
# 10                           148000.0      STEM
# 11                           143000.0      HASS
# 12                           162000.0      STEM
# 13                           154000.0      STEM
# 14                           171000.0  Business
# 15                           107000.0      HASS
# 16                           153000.0      HASS
# 17                           210000.0  Business
# 18                           102000.0      HASS
# 19                           168000.0      STEM
# 20                           133000.0      HASS
# 21                           136000.0      HASS
# 22                           195000.0  Business
# 23                           111000.0  Business
# 24                           132000.0      HASS
# 25                           156000.0      STEM
# 26                           112000.0      HASS
# 27                           101000.0  Business
# 28                           149000.0      HASS
# 29                           124000.0  Business
# 30                           173000.0      STEM
# 31                           129000.0      STEM
# 32                           107000.0      HASS
# 33                           157000.0      HASS
# 34                           145000.0      HASS
# 35                           146000.0      STEM
# 36                           175000.0  Business
# 37                           183000.0      STEM
# 38                           163000.0      STEM
# 39                           134000.0      HASS
# 40                            98300.0  Business
# 41                            99200.0      HASS
# 42                           168000.0      HASS
# 43                           124000.0      STEM
# 44                           178000.0      STEM
# 45                           168000.0      HASS
# 46                           127000.0      HASS
# 47                            96400.0      HASS
# 48                           118000.0      HASS
# 49                            96400.0      HASS
# 50                                NaN       NaN

# %%
#Lets look at the head:
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
#Basic info:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Undergraduate Major                51 non-null     object
#  1   Starting Median Salary             50 non-null     float64
#  2   Mid-Career Median Salary           50 non-null     float64
#  3   Mid-Career 10th Percentile Salary  50 non-null     float64
#  4   Mid-Career 90th Percentile Salary  50 non-null     float64
#  5   Group                              50 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 2.5+ KB

# %%
#Columns:
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.shape
# Out:
# (51, 6)

# %%
#Check if there are any null values:
df.isnull()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# 12                False                   False                     False
# 13                False                   False                     False
# 14                False                   False                     False
# 15                False                   False                     False
# 16                False                   False                     False
# 17                False                   False                     False
# 18                False                   False                     False
# 19                False                   False                     False
# 20                False                   False                     False
# 21                False                   False                     False
# 22                False                   False                     False
# 23                False                   False                     False
# 24                False                   False                     False
# 25                False                   False                     False
# 26                False                   False                     False
# 27                False                   False                     False
# 28                False                   False                     False
# 29                False                   False                     False
# 30                False                   False                     False
# 31                False                   False                     False
# 32                False                   False                     False
# 33                False                   False                     False
# 34                False                   False                     False
# 35                False                   False                     False
# 36                False                   False                     False
# 37                False                   False                     False
# 38                False                   False                     False
# 39                False                   False                     False
# 40                False                   False                     False
# 41                False                   False                     False
# 42                False                   False                     False
# 43                False                   False                     False
# 44                False                   False                     False
# 45                False                   False                     False
# 46                False                   False                     False
# 47                False                   False                     False
# 48                False                   False                     False
# 49                False                   False                     False
# 50                False                    True                      True
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# 5                               False                              False
# 6                               False                              False
# 7                               False                              False
# 8                               False                              False
# 9                               False                              False
# 10                              False                              False
# 11                              False                              False
# 12                              False                              False
# 13                              False                              False
# 14                              False                              False
# 15                              False                              False
# 16                              False                              False
# 17                              False                              False
# 18                              False                              False
# 19                              False                              False
# 20                              False                              False
# 21                              False                              False
# 22                              False                              False
# 23                              False                              False
# 24                              False                              False
# 25                              False                              False
# 26                              False                              False
# 27                              False                              False
# 28                              False                              False
# 29                              False                              False
# 30                              False                              False
# 31                              False                              False
# 32                              False                              False
# 33                              False                              False
# 34                              False                              False
# 35                              False                              False
# 36                              False                              False
# 37                              False                              False
# 38                              False                              False
# 39                              False                              False
# 40                              False                              False
# 41                              False                              False
# 42                              False                              False
# 43                              False                              False
# 44                              False                              False
# 45                              False                              False
# 46                              False                              False
# 47                              False                              False
# 48                              False                              False
# 49                              False                              False
# 50                               True                               True
#
#     Group
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41  False
# 42  False
# 43  False
# 44  False
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False
# 50   True

# %%
#50th row has null value:
df.iloc[50]
# Out:
# Undergraduate Major                  Source: PayScale Inc.
# Starting Median Salary                                 NaN
# Mid-Career Median Salary                               NaN
# Mid-Career 10th Percentile Salary                      NaN
# Mid-Career 90th Percentile Salary                      NaN
# Group                                                  NaN
# Name: 50, dtype: object

# %%
#Lets drop the 50th row for now:
df.dropna(axis=0, inplace=True)

# %%
#check if the nan's are removed:
df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
#college major with highest median salary:
df.loc[df.iloc[:,1].idxmax(), 'Undergraduate Major']
# Out:
# 'Physician Assistant'

# %%
df.iloc[df.iloc[:,1].idxmax()]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
#colllege major with highest-mid career (10+ years) salary:

df.loc[df.loc[:,'Mid-Career Median Salary'].idxmax(), 'Undergraduate Major']
# Out:
# 'Chemical Engineering'

# %%
df.iloc[df.loc[:,'Mid-Career Median Salary'].idxmax()]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
#college major with lowest median salary:
df.loc[df.iloc[:,1].idxmin(),:]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
#how much can a major in Spanish can expect to earn:
df.iloc[49,1]
# Out:
# 34000.0

# %%
#lowest mid career salary:
df.iloc[df.iloc[:,2].idxmin(),:]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
#how much can a major in education expect to earn:
df.iloc[18,1]
# Out:
# 34900.0

# %%
# major with least risk(least difference between the salary of 10th percentile and 90th percentile):

# %%
#add a column called risk which calculates this difference:
df.loc[:,'risk']=df.iloc[:,4]-df.iloc[:,3]

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# 13                      Computer Science                 55900.0
# 14                          Construction                 53700.0
# 15                      Criminal Justice                 35000.0
# 16                                 Drama                 35900.0
# 17                             Economics                 50100.0
# 18                             Education                 34900.0
# 19                Electrical Engineering                 60900.0
# 20                               English                 38000.0
# 21                                  Film                 37900.0
# 22                               Finance                 47900.0
# 23                              Forestry                 39100.0
# 24                             Geography                 41200.0
# 25                               Geology                 43500.0
# 26                        Graphic Design                 35700.0
# 27            Health Care Administration                 38800.0
# 28                               History                 39200.0
# 29                 Hospitality & Tourism                 37800.0
# 30                Industrial Engineering                 57700.0
# 31           Information Technology (IT)                 49100.0
# 32                       Interior Design                 36100.0
# 33               International Relations                 40900.0
# 34                            Journalism                 35600.0
# 35  Management Information Systems (MIS)                 49200.0
# 36                             Marketing                 40800.0
# 37                                  Math                 45400.0
# 38                Mechanical Engineering                 57900.0
# 39                                 Music                 35900.0
# 40                               Nursing                 54200.0
# 41                             Nutrition                 39900.0
# 42                            Philosophy                 39900.0
# 43                   Physician Assistant                 74300.0
# 44                               Physics                 50300.0
# 45                     Political Science                 40800.0
# 46                            Psychology                 35900.0
# 47                              Religion                 34100.0
# 48                             Sociology                 36500.0
# 49                               Spanish                 34000.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                    77100.0                            42200.0
# 1                   101000.0                            64300.0
# 2                    71900.0                            36300.0
# 3                    61500.0                            33800.0
# 4                    76800.0                            50600.0
# 5                    64900.0                            28800.0
# 6                    64800.0                            36900.0
# 7                    72100.0                            38800.0
# 8                   107000.0                            71900.0
# 9                    79900.0                            45300.0
# 10                   90500.0                            63400.0
# 11                   70000.0                            37500.0
# 12                  105000.0                            66100.0
# 13                   95500.0                            56000.0
# 14                   88900.0                            56300.0
# 15                   56300.0                            32200.0
# 16                   56900.0                            36700.0
# 17                   98600.0                            50600.0
# 18                   52000.0                            29300.0
# 19                  103000.0                            69300.0
# 20                   64700.0                            33400.0
# 21                   68500.0                            33900.0
# 22                   88300.0                            47200.0
# 23                   62600.0                            41000.0
# 24                   65500.0                            40000.0
# 25                   79500.0                            45000.0
# 26                   59800.0                            36000.0
# 27                   60600.0                            34600.0
# 28                   71000.0                            37000.0
# 29                   57500.0                            35500.0
# 30                   94700.0                            57100.0
# 31                   74800.0                            44500.0
# 32                   53200.0                            35700.0
# 33                   80900.0                            38200.0
# 34                   66700.0                            38400.0
# 35                   82300.0                            45300.0
# 36                   79600.0                            42100.0
# 37                   92400.0                            45200.0
# 38                   93600.0                            63700.0
# 39                   55000.0                            26700.0
# 40                   67000.0                            47600.0
# 41                   55300.0                            33900.0
# 42                   81200.0                            35500.0
# 43                   91700.0                            66400.0
# 44                   97300.0                            56000.0
# 45                   78200.0                            41200.0
# 46                   60400.0                            31600.0
# 47                   52000.0                            29700.0
# 48                   58200.0                            30700.0
# 49                   53100.0                            31000.0
#
#     Mid-Career 90th Percentile Salary     Group      risk
# 0                            152000.0  Business  109800.0
# 1                            161000.0      STEM   96700.0
# 2                            150000.0  Business  113700.0
# 3                            138000.0      HASS  104200.0
# 4                            136000.0  Business   85400.0
# 5                            125000.0      HASS   96200.0
# 6                            135000.0      STEM   98100.0
# 7                            147000.0  Business  108200.0
# 8                            194000.0      STEM  122100.0
# 9                            148000.0      STEM  102700.0
# 10                           148000.0      STEM   84600.0
# 11                           143000.0      HASS  105500.0
# 12                           162000.0      STEM   95900.0
# 13                           154000.0      STEM   98000.0
# 14                           171000.0  Business  114700.0
# 15                           107000.0      HASS   74800.0
# 16                           153000.0      HASS  116300.0
# 17                           210000.0  Business  159400.0
# 18                           102000.0      HASS   72700.0
# 19                           168000.0      STEM   98700.0
# 20                           133000.0      HASS   99600.0
# 21                           136000.0      HASS  102100.0
# 22                           195000.0  Business  147800.0
# 23                           111000.0  Business   70000.0
# 24                           132000.0      HASS   92000.0
# 25                           156000.0      STEM  111000.0
# 26                           112000.0      HASS   76000.0
# 27                           101000.0  Business   66400.0
# 28                           149000.0      HASS  112000.0
# 29                           124000.0  Business   88500.0
# 30                           173000.0      STEM  115900.0
# 31                           129000.0      STEM   84500.0
# 32                           107000.0      HASS   71300.0
# 33                           157000.0      HASS  118800.0
# 34                           145000.0      HASS  106600.0
# 35                           146000.0      STEM  100700.0
# 36                           175000.0  Business  132900.0
# 37                           183000.0      STEM  137800.0
# 38                           163000.0      STEM   99300.0
# 39                           134000.0      HASS  107300.0
# 40                            98300.0  Business   50700.0
# 41                            99200.0      HASS   65300.0
# 42                           168000.0      HASS  132500.0
# 43                           124000.0      STEM   57600.0
# 44                           178000.0      STEM  122000.0
# 45                           168000.0      HASS  126800.0
# 46                           127000.0      HASS   95400.0
# 47                            96400.0      HASS   66700.0
# 48                           118000.0      HASS   87300.0
# 49                            96400.0      HASS   65400.0

# %%
low_risk = df.sort_values(by=["risk"], ascending=True)

# %%
#Low risk majors:
low_risk.iloc[:,[0,6]].head(10)
# Out:
#            Undergraduate Major     risk
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0
# 47                    Religion  66700.0
# 23                    Forestry  70000.0
# 32             Interior Design  71300.0
# 18                   Education  72700.0
# 15            Criminal Justice  74800.0

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group', 'risk'],
#       dtype='object')

# %%
# Major with highest potential in their pay:

highest_potential = df.sort_values(by=['Mid-Career 90th Percentile Salary'], ascending=False)

# %%
highest_potential.head(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17             Economics                 50100.0                   98600.0
# 22               Finance                 47900.0                   88300.0
# 8   Chemical Engineering                 63200.0                  107000.0
# 37                  Math                 45400.0                   92400.0
# 44               Physics                 50300.0                   97300.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 8                             71900.0                           194000.0
# 37                            45200.0                           183000.0
# 44                            56000.0                           178000.0
#
#        Group      risk
# 17  Business  159400.0
# 22  Business  147800.0
# 8       STEM  122100.0
# 37      STEM  137800.0
# 44      STEM  122000.0

# %%
#greatest spread in the pay (highest risk):
greatest_spread = df.sort_values(by='risk', ascending=False)

# %%
greatest_spread.head(5)
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17           Economics                 50100.0                   98600.0
# 22             Finance                 47900.0                   88300.0
# 37                Math                 45400.0                   92400.0
# 36           Marketing                 40800.0                   79600.0
# 42          Philosophy                 39900.0                   81200.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 37                            45200.0                           183000.0
# 36                            42100.0                           175000.0
# 42                            35500.0                           168000.0
#
#        Group      risk
# 17  Business  159400.0
# 22  Business  147800.0
# 37      STEM  137800.0
# 36  Business  132900.0
# 42      HASS  132500.0

# %%
#The 3 majors among the top: economics, math, finance are present -
# in both the tables. Indicating there are graduates from these majors who -
# are high earners but there are also some who are not
# earning much!.

# %%
#Highest mid-career salary majors:
mid_highest=df.sort_values(by="Mid-Career Median Salary", ascending=False)
mid_highest.iloc[:,[0,2]].head()
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
# 1    Aerospace Engineering                  101000.0
# 17               Economics                   98600.0

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group', 'risk'],
#       dtype='object')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
#stats on various groups: Business, STEM and HASS(humanities, arts and social sciences)
df.groupby('Group').apply(lambda x:x.iloc[:,[2,3,4,6]].mean())
# Out:
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                 75,083.33                          43,566.67
# HASS                     62,968.18                          34,145.45
# STEM                     90,812.50                          56,025.00
#
#           Mid-Career 90th Percentile Salary       risk
# Group
# Business                         147,525.00 103,958.33
# HASS                             129,363.64  95,218.18
# STEM                             157,625.00 101,600.00

# %% [markdown]
# ## Using payscale website to webscrape the 2023 data on university majors and their median pay at different points of their careers:

# %%
#webscrape
import requests
import json
from bs4 import BeautifulSoup 
l=[]
for i in range(1,33):
  payscale= requests.get("https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors/page/" + str(i))
  soup = BeautifulSoup(payscale.text, 'html.parser')
  for e in enumerate((soup.find(type="application/json").getText().split("]")[0].split("}"))):
      if e[1] != "":
        if e[0] == 0:
          l.append(json.loads(e[1].split("[")[1] + "}"))
        else:
          l.append(json.loads("{" + e[1].split(",{")[1] + "}"))

# %%
l
# Out:
# [{'id': 5088,
#   'degreeType': 'Bachelors',
#   'major': 'Petroleum Engineering',
#   'earlyCareerMedianPay': 97500,
#   'midCareerMedianPay': 212500,
#   'fiveToTenYearMedianPay': 151800,
#   'tenToTwentyYearMedianPay': 197600,
#   'twentyPlusYearMedianPay': 226100,
#   'percentHighMeaning': 0.61,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Petroleum_Engineering/Salary',
#   'rank': 1,
#   'tie': False},
#  {'id': 5614,
#   'degreeType': 'Bachelors',
#   'major': 'Operations Research & Industrial Engineering',
#   'earlyCareerMedianPay': 98300,
#   'midCareerMedianPay': 191800,
#   'fiveToTenYearMedianPay': 153700,
#   'tenToTwentyYearMedianPay': 188500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.21,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Operations_Research_%26_Industrial_Engineering/Salary',
#   'rank': 2,
#   'tie': False},
#  {'id': 5615,
#   'degreeType': 'Bachelors',
#   'major': 'Interaction Design',
#   'earlyCareerMedianPay': 74700,
#   'midCareerMedianPay': 173600,
#   'fiveToTenYearMedianPay': 118400,
#   'tenToTwentyYearMedianPay': 173600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Interaction_Design/Salary',
#   'rank': 3,
#   'tie': False},
#  {'id': 5616,
#   'degreeType': 'Bachelors',
#   'major': 'Applied Economics and Management',
#   'earlyCareerMedianPay': 76500,
#   'midCareerMedianPay': 164400,
#   'fiveToTenYearMedianPay': 112800,
#   'tenToTwentyYearMedianPay': 164400,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Applied_Economics_and_Management/Salary',
#   'rank': 4,
#   'tie': False},
#  {'id': 5617,
#   'degreeType': 'Bachelors',
#   'major': 'Building Science',
#   'earlyCareerMedianPay': 69000,
#   'midCareerMedianPay': 163100,
#   'fiveToTenYearMedianPay': 99100,
#   'tenToTwentyYearMedianPay': 152600,
#   'twentyPlusYearMedianPay': 179000,
#   'percentHighMeaning': 0.47,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Building_Science/Salary',
#   'rank': 5,
#   'tie': False},
#  {'id': 5618,
#   'degreeType': 'Bachelors',
#   'major': 'Actuarial Mathematics',
#   'earlyCareerMedianPay': 70700,
#   'midCareerMedianPay': 160000,
#   'fiveToTenYearMedianPay': 104900,
#   'tenToTwentyYearMedianPay': 178600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.52,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Actuarial_Mathematics/Salary',
#   'rank': 6,
#   'tie': True},
#  {'id': 5619,
#   'degreeType': 'Bachelors',
#   'major': 'Operations Research',
#   'earlyCareerMedianPay': 92200,
#   'midCareerMedianPay': 160000,
#   'fiveToTenYearMedianPay': 123300,
#   'tenToTwentyYearMedianPay': 161800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.57,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Operations_Research/Salary',
#   'rank': 6,
#   'tie': True},
#  {'id': 5620,
#   'degreeType': 'Bachelors',
#   'major': 'Systems Engineering',
#   'earlyCareerMedianPay': 87000,
#   'midCareerMedianPay': 159100,
#   'fiveToTenYearMedianPay': 118900,
#   'tenToTwentyYearMedianPay': 145500,
#   'twentyPlusYearMedianPay': 165900,
#   'percentHighMeaning': 0.58,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Systems_Engineering/Salary',
#   'rank': 8,
#   'tie': False},
#  {'id': 5621,
#   'degreeType': 'Bachelors',
#   'major': 'Optical Science & Engineering',
#   'earlyCareerMedianPay': 79600,
#   'midCareerMedianPay': 158300,
#   'fiveToTenYearMedianPay': 112200,
#   'tenToTwentyYearMedianPay': 149600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.73,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Optical_Science_%26_Engineering/Salary',
#   'rank': 9,
#   'tie': False},
#  {'id': 5622,
#   'degreeType': 'Bachelors',
#   'major': 'Information & Computer Science',
#   'earlyCareerMedianPay': 76000,
#   'midCareerMedianPay': 157800,
#   'fiveToTenYearMedianPay': 131700,
#   'tenToTwentyYearMedianPay': 146700,
#   'twentyPlusYearMedianPay': 171200,
#   'percentHighMeaning': 0.63,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Information_%26_Computer_Science/Salary',
#   'rank': 10,
#   'tie': False},
#  {'id': 5623,
#   'degreeType': 'Bachelors',
#   'major': 'Aeronautics & Astronautics',
#   'earlyCareerMedianPay': 88200,
#   'midCareerMedianPay': 156900,
#   'fiveToTenYearMedianPay': 108500,
#   'tenToTwentyYearMedianPay': 136000,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.56,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Aeronautics_%26_Astronautics/Salary',
#   'rank': 11,
#   'tie': False},
#  {'id': 5624,
#   'degreeType': 'Bachelors',
#   'major': 'Aerospace Studies',
#   'earlyCareerMedianPay': 62600,
#   'midCareerMedianPay': 154300,
#   'fiveToTenYearMedianPay': 76000,
#   'tenToTwentyYearMedianPay': 153800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Aerospace_Studies/Salary',
#   'rank': 12,
#   'tie': False},
#  {'id': 5625,
#   'degreeType': 'Bachelors',
#   'major': 'Pharmacy',
#   'earlyCareerMedianPay': 69400,
#   'midCareerMedianPay': 154000,
#   'fiveToTenYearMedianPay': 130100,
#   'tenToTwentyYearMedianPay': 153800,
#   'twentyPlusYearMedianPay': 154300,
#   'percentHighMeaning': 0.79,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Pharmacy/Salary',
#   'rank': 13,
#   'tie': False},
#  {'id': 5626,
#   'degreeType': 'Bachelors',
#   'major': 'Cognitive Science',
#   'earlyCareerMedianPay': 78000,
#   'midCareerMedianPay': 153800,
#   'fiveToTenYearMedianPay': 111000,
#   'tenToTwentyYearMedianPay': 139400,
#   'twentyPlusYearMedianPay': 179000,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Cognitive_Science/Salary',
#   'rank': 14,
#   'tie': False},
#  {'id': 5627,
#   'degreeType': 'Bachelors',
#   'major': 'Managerial Economics',
#   'earlyCareerMedianPay': 74700,
#   'midCareerMedianPay': 153300,
#   'fiveToTenYearMedianPay': 103700,
#   'tenToTwentyYearMedianPay': 138800,
#   'twentyPlusYearMedianPay': 228400,
#   'percentHighMeaning': 0.38,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Managerial_Economics/Salary',
#   'rank': 15,
#   'tie': False},
#  {'id': 5628,
#   'degreeType': 'Bachelors',
#   'major': 'Quantitative Economics',
#   'earlyCareerMedianPay': 74500,
#   'midCareerMedianPay': 152700,
#   'fiveToTenYearMedianPay': 101400,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Quantitative_Economics/Salary',
#   'rank': 16,
#   'tie': False},
#  {'id': 5629,
#   'degreeType': 'Bachelors',
#   'major': 'Econometrics',
#   'earlyCareerMedianPay': 72000,
#   'midCareerMedianPay': 152100,
#   'fiveToTenYearMedianPay': 97300,
#   'tenToTwentyYearMedianPay': 138400,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.35,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Econometrics/Salary',
#   'rank': 17,
#   'tie': False},
#  {'id': 5630,
#   'degreeType': 'Bachelors',
#   'major': 'Foreign Affairs',
#   'earlyCareerMedianPay': 62900,
#   'midCareerMedianPay': 152000,
#   'fiveToTenYearMedianPay': 94400,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.32,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Foreign_Affairs/Salary',
#   'rank': 18,
#   'tie': False},
#  {'id': 5631,
#   'degreeType': 'Bachelors',
#   'major': 'Chemical Engineering',
#   'earlyCareerMedianPay': 85600,
#   'midCareerMedianPay': 151800,
#   'fiveToTenYearMedianPay': 111000,
#   'tenToTwentyYearMedianPay': 141600,
#   'twentyPlusYearMedianPay': 170200,
#   'percentHighMeaning': 0.55,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Chemical_Engineering/Salary',
#   'rank': 19,
#   'tie': False},
#  {'id': 5632,
#   'degreeType': 'Bachelors',
#   'major': 'Public Accounting',
#   'earlyCareerMedianPay': 69700,
#   'midCareerMedianPay': 151200,
#   'fiveToTenYearMedianPay': 77600,
#   'tenToTwentyYearMedianPay': 101200,
#   'twentyPlusYearMedianPay': 203600,
#   'percentHighMeaning': 0.47,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Public_Accounting/Salary',
#   'rank': 20,
#   'tie': False},
#  {'id': 5633,
#   'degreeType': 'Bachelors',
#   'major': 'Political Economy',
#   'earlyCareerMedianPay': 73100,
#   'midCareerMedianPay': 150600,
#   'fiveToTenYearMedianPay': 118300,
#   'tenToTwentyYearMedianPay': 147400,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.31,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Political_Economy/Salary',
#   'rank': 21,
#   'tie': False},
#  {'id': 5634,
#   'degreeType': 'Bachelors',
#   'major': 'Corporate Accounting & Finance',
#   'earlyCareerMedianPay': 76800,
#   'midCareerMedianPay': 149600,
#   'fiveToTenYearMedianPay': 98000,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Corporate_Accounting_%26_Finance/Salary',
#   'rank': 22,
#   'tie': False},
#  {'id': 5613,
#   'degreeType': 'Bachelors',
#   'major': 'Actuarial Science',
#   'earlyCareerMedianPay': 76700,
#   'midCareerMedianPay': 149000,
#   'fiveToTenYearMedianPay': 109000,
#   'tenToTwentyYearMedianPay': 143900,
#   'twentyPlusYearMedianPay': 156500,
#   'percentHighMeaning': 0.42,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Actuarial_Science/Salary',
#   'rank': 23,
#   'tie': False},
#  {'id': 5635,
#   'degreeType': 'Bachelors',
#   'major': 'Computer Engineering (CE)',
#   'earlyCareerMedianPay': 89100,
#   'midCareerMedianPay': 148500,
#   'fiveToTenYearMedianPay': 113800,
#   'tenToTwentyYearMedianPay': 143200,
#   'twentyPlusYearMedianPay': 166900,
#   'percentHighMeaning': 0.46,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computer_Engineering_(CE)/Salary',
#   'rank': 24,
#   'tie': False},
#  {'id': 5612,
#   'degreeType': 'Bachelors',
#   'major': 'Electrical Power Engineering',
#   'earlyCareerMedianPay': 84700,
#   'midCareerMedianPay': 148300,
#   'fiveToTenYearMedianPay': 111700,
#   'tenToTwentyYearMedianPay': 128500,
#   'twentyPlusYearMedianPay': 170200,
#   'percentHighMeaning': 0.72,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Electrical_Power_Engineering/Salary',
#   'rank': 25,
#   'tie': False},
#  {'id': 5610,
#   'degreeType': 'Bachelors',
#   'major': 'Computer Science (CS) & Engineering',
#   'earlyCareerMedianPay': 90500,
#   'midCareerMedianPay': 148200,
#   'fiveToTenYearMedianPay': 113000,
#   'tenToTwentyYearMedianPay': 139400,
#   'twentyPlusYearMedianPay': 163100,
#   'percentHighMeaning': 0.44,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computer_Science_(CS)_%26_Engineering/Salary',
#   'rank': 26,
#   'tie': False},
#  {'id': 5589,
#   'degreeType': 'Bachelors',
#   'major': 'Marine Transportation Management',
#   'earlyCareerMedianPay': 78700,
#   'midCareerMedianPay': 148000,
#   'fiveToTenYearMedianPay': 99700,
#   'tenToTwentyYearMedianPay': 136700,
#   'twentyPlusYearMedianPay': 153400,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Marine_Transportation_Management/Salary',
#   'rank': 27,
#   'tie': False},
#  {'id': 5590,
#   'degreeType': 'Bachelors',
#   'major': 'Marine Engineering',
#   'earlyCareerMedianPay': 87900,
#   'midCareerMedianPay': 147500,
#   'fiveToTenYearMedianPay': 103800,
#   'tenToTwentyYearMedianPay': 133300,
#   'twentyPlusYearMedianPay': 167700,
#   'percentHighMeaning': 0.57,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Marine_Engineering/Salary',
#   'rank': 28,
#   'tie': True},
#  {'id': 5591,
#   'degreeType': 'Bachelors',
#   'major': 'Operations & Information Systems Management',
#   'earlyCareerMedianPay': 78800,
#   'midCareerMedianPay': 147500,
#   'fiveToTenYearMedianPay': 98500,
#   'tenToTwentyYearMedianPay': 147500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.24,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Operations_%26_Information_Systems_Management/Salary',
#   'rank': 28,
#   'tie': True},
#  {'id': 5592,
#   'degreeType': 'Bachelors',
#   'major': 'Electrical & Computer Engineering (ECE)',
#   'earlyCareerMedianPay': 88100,
#   'midCareerMedianPay': 147000,
#   'fiveToTenYearMedianPay': 112000,
#   'tenToTwentyYearMedianPay': 139700,
#   'twentyPlusYearMedianPay': 162000,
#   'percentHighMeaning': 0.49,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Electrical_%26_Computer_Engineering_(ECE)/Salary',
#   'rank': 30,
#   'tie': False},
#  {'id': 5593,
#   'degreeType': 'Bachelors',
#   'major': 'Entrepreneurship & Marketing',
#   'earlyCareerMedianPay': 63200,
#   'midCareerMedianPay': 145800,
#   'fiveToTenYearMedianPay': 84400,
#   'tenToTwentyYearMedianPay': 119600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.45,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Entrepreneurship_%26_Marketing/Salary',
#   'rank': 31,
#   'tie': False},
#  {'id': 5594,
#   'degreeType': 'Bachelors',
#   'major': 'Astronomy',
#   'earlyCareerMedianPay': 75300,
#   'midCareerMedianPay': 145600,
#   'fiveToTenYearMedianPay': 88100,
#   'tenToTwentyYearMedianPay': 149000,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.52,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Astronomy/Salary',
#   'rank': 32,
#   'tie': False},
#  {'id': 5595,
#   'degreeType': 'Bachelors',
#   'major': 'Mechatronics',
#   'earlyCareerMedianPay': 80900,
#   'midCareerMedianPay': 144300,
#   'fiveToTenYearMedianPay': 97000,
#   'tenToTwentyYearMedianPay': 144300,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.46,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mechatronics/Salary',
#   'rank': 33,
#   'tie': False},
#  {'id': 5596,
#   'degreeType': 'Bachelors',
#   'major': 'Computational & Applied Mathematics',
#   'earlyCareerMedianPay': 85700,
#   'midCareerMedianPay': 144100,
#   'fiveToTenYearMedianPay': 105000,
#   'tenToTwentyYearMedianPay': 160800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.46,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computational_%26_Applied_Mathematics/Salary',
#   'rank': 34,
#   'tie': False},
#  {'id': 5597,
#   'degreeType': 'Bachelors',
#   'major': 'Aeronautical Engineering',
#   'earlyCareerMedianPay': 84200,
#   'midCareerMedianPay': 143400,
#   'fiveToTenYearMedianPay': 103700,
#   'tenToTwentyYearMedianPay': 127500,
#   'twentyPlusYearMedianPay': 151600,
#   'percentHighMeaning': 0.63,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Aeronautical_Engineering/Salary',
#   'rank': 35,
#   'tie': False},
#  {'id': 5598,
#   'degreeType': 'Bachelors',
#   'major': 'Welding Engineering',
#   'earlyCareerMedianPay': 86600,
#   'midCareerMedianPay': 143300,
#   'fiveToTenYearMedianPay': 102000,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': 188400,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Welding_Engineering/Salary',
#   'rank': 36,
#   'tie': False},
#  {'id': 5599,
#   'degreeType': 'Bachelors',
#   'major': 'Electrical Engineering (EE)',
#   'earlyCareerMedianPay': 84900,
#   'midCareerMedianPay': 143000,
#   'fiveToTenYearMedianPay': 106400,
#   'tenToTwentyYearMedianPay': 132600,
#   'twentyPlusYearMedianPay': 157800,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Electrical_Engineering_(EE)/Salary',
#   'rank': 37,
#   'tie': False},
#  {'id': 5600,
#   'degreeType': 'Bachelors',
#   'major': 'Electrical & Electronics Engineering (EEE)',
#   'earlyCareerMedianPay': 83900,
#   'midCareerMedianPay': 142900,
#   'fiveToTenYearMedianPay': 100200,
#   'tenToTwentyYearMedianPay': 126400,
#   'twentyPlusYearMedianPay': 153700,
#   'percentHighMeaning': 0.57,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Electrical_%26_Electronics_Engineering_(EEE)/Salary',
#   'rank': 38,
#   'tie': False},
#  {'id': 5601,
#   'degreeType': 'Bachelors',
#   'major': 'Naval Architecture & Marine Engineering',
#   'earlyCareerMedianPay': 82800,
#   'midCareerMedianPay': 142800,
#   'fiveToTenYearMedianPay': 104300,
#   'tenToTwentyYearMedianPay': 134100,
#   'twentyPlusYearMedianPay': 145500,
#   'percentHighMeaning': 0.49,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Naval_Architecture_%26_Marine_Engineering/Salary',
#   'rank': 39,
#   'tie': False},
#  {'id': 5602,
#   'degreeType': 'Bachelors',
#   'major': 'Instrumentation & Control Engineering',
#   'earlyCareerMedianPay': 82800,
#   'midCareerMedianPay': 141900,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': 115300,
#   'twentyPlusYearMedianPay': 166600,
#   'percentHighMeaning': 0.44,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Instrumentation_%26_Control_Engineering/Salary',
#   'rank': 40,
#   'tie': False},
#  {'id': 5603,
#   'degreeType': 'Bachelors',
#   'major': 'Construction Engineering Management',
#   'earlyCareerMedianPay': 78100,
#   'midCareerMedianPay': 141800,
#   'fiveToTenYearMedianPay': 90900,
#   'tenToTwentyYearMedianPay': 128200,
#   'twentyPlusYearMedianPay': 155100,
#   'percentHighMeaning': 0.53,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Construction_Engineering_Management/Salary',
#   'rank': 41,
#   'tie': False},
#  {'id': 5604,
#   'degreeType': 'Bachelors',
#   'major': 'Computer Science (CS) & Mathematics',
#   'earlyCareerMedianPay': 80300,
#   'midCareerMedianPay': 141000,
#   'fiveToTenYearMedianPay': 103500,
#   'tenToTwentyYearMedianPay': 133400,
#   'twentyPlusYearMedianPay': 150100,
#   'percentHighMeaning': 0.44,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computer_Science_(CS)_%26_Mathematics/Salary',
#   'rank': 42,
#   'tie': False},
#  {'id': 5605,
#   'degreeType': 'Bachelors',
#   'major': 'Engineering Physics',
#   'earlyCareerMedianPay': 78600,
#   'midCareerMedianPay': 140300,
#   'fiveToTenYearMedianPay': 101100,
#   'tenToTwentyYearMedianPay': 122300,
#   'twentyPlusYearMedianPay': 161700,
#   'percentHighMeaning': 0.48,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Engineering_Physics/Salary',
#   'rank': 43,
#   'tie': False},
#  {'id': 5606,
#   'degreeType': 'Bachelors',
#   'major': 'Mechanical & Aeronautical Engineering',
#   'earlyCareerMedianPay': 80900,
#   'midCareerMedianPay': 139900,
#   'fiveToTenYearMedianPay': 97000,
#   'tenToTwentyYearMedianPay': 128900,
#   'twentyPlusYearMedianPay': 176900,
#   'percentHighMeaning': 0.62,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mechanical_%26_Aeronautical_Engineering/Salary',
#   'rank': 44,
#   'tie': False},
#  {'id': 5607,
#   'degreeType': 'Bachelors',
#   'major': 'Chemical & Biomolecular Engineering',
#   'earlyCareerMedianPay': 86000,
#   'midCareerMedianPay': 139700,
#   'fiveToTenYearMedianPay': 111300,
#   'tenToTwentyYearMedianPay': 132500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.51,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Chemical_%26_Biomolecular_Engineering/Salary',
#   'rank': 45,
#   'tie': True},
#  {'id': 5608,
#   'degreeType': 'Bachelors',
#   'major': 'Computer Science (CS)',
#   'earlyCareerMedianPay': 85400,
#   'midCareerMedianPay': 139700,
#   'fiveToTenYearMedianPay': 110600,
#   'tenToTwentyYearMedianPay': 133900,
#   'twentyPlusYearMedianPay': 150800,
#   'percentHighMeaning': 0.42,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computer_Science_(CS)/Salary',
#   'rank': 45,
#   'tie': True},
#  {'id': 5609,
#   'degreeType': 'Bachelors',
#   'major': 'Jazz Studies',
#   'earlyCareerMedianPay': 60000,
#   'midCareerMedianPay': 139400,
#   'fiveToTenYearMedianPay': 63200,
#   'tenToTwentyYearMedianPay': 142400,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.51,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Jazz_Studies/Salary',
#   'rank': 47,
#   'tie': False},
#  {'id': 5611,
#   'degreeType': 'Bachelors',
#   'major': 'Bioscience',
#   'earlyCareerMedianPay': 59900,
#   'midCareerMedianPay': 139300,
#   'fiveToTenYearMedianPay': 82300,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Bioscience/Salary',
#   'rank': 48,
#   'tie': False},
#  {'id': 5637,
#   'degreeType': 'Bachelors',
#   'major': 'Information Management',
#   'earlyCareerMedianPay': 67000,
#   'midCareerMedianPay': 139000,
#   'fiveToTenYearMedianPay': 94700,
#   'tenToTwentyYearMedianPay': 126500,
#   'twentyPlusYearMedianPay': 163600,
#   'percentHighMeaning': 0.33,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Information_Management/Salary',
#   'rank': 49,
#   'tie': False},
#  {'id': 5661,
#   'degreeType': 'Bachelors',
#   'major': 'Aerospace Engineering',
#   'earlyCareerMedianPay': 83500,
#   'midCareerMedianPay': 138100,
#   'fiveToTenYearMedianPay': 106500,
#   'tenToTwentyYearMedianPay': 132000,
#   'twentyPlusYearMedianPay': 165800,
#   'percentHighMeaning': 0.53,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Aerospace_Engineering/Salary',
#   'rank': 50,
#   'tie': False},
#  {'id': 5638,
#   'degreeType': 'Bachelors',
#   'major': 'Ocean Engineering (OE)',
#   'earlyCareerMedianPay': 78500,
#   'midCareerMedianPay': 137800,
#   'fiveToTenYearMedianPay': 93200,
#   'tenToTwentyYearMedianPay': 118600,
#   'twentyPlusYearMedianPay': 159300,
#   'percentHighMeaning': 0.49,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Ocean_Engineering_(OE)/Salary',
#   'rank': 51,
#   'tie': True},
#  {'id': 5664,
#   'degreeType': 'Bachelors',
#   'major': 'Pharmacology',
#   'earlyCareerMedianPay': 63500,
#   'midCareerMedianPay': 137800,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Pharmacology/Salary',
#   'rank': 51,
#   'tie': True},
#  {'id': 5665,
#   'degreeType': 'Bachelors',
#   'major': 'Nuclear Engineering',
#   'earlyCareerMedianPay': 85200,
#   'midCareerMedianPay': 137600,
#   'fiveToTenYearMedianPay': 104700,
#   'tenToTwentyYearMedianPay': 128200,
#   'twentyPlusYearMedianPay': 153700,
#   'percentHighMeaning': 0.55,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Nuclear_Engineering/Salary',
#   'rank': 53,
#   'tie': False},
#  {'id': 5666,
#   'degreeType': 'Bachelors',
#   'major': 'Bioengineering (BioE)',
#   'earlyCareerMedianPay': 79500,
#   'midCareerMedianPay': 137300,
#   'fiveToTenYearMedianPay': 102500,
#   'tenToTwentyYearMedianPay': 136200,
#   'twentyPlusYearMedianPay': 168400,
#   'percentHighMeaning': 0.67,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Bioengineering_(BioE)/Salary',
#   'rank': 54,
#   'tie': False},
#  {'id': 5667,
#   'degreeType': 'Bachelors',
#   'major': 'Applied Mathematics',
#   'earlyCareerMedianPay': 77200,
#   'midCareerMedianPay': 137000,
#   'fiveToTenYearMedianPay': 107200,
#   'tenToTwentyYearMedianPay': 129500,
#   'twentyPlusYearMedianPay': 151500,
#   'percentHighMeaning': 0.4,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Applied_Mathematics/Salary',
#   'rank': 55,
#   'tie': False},
#  {'id': 5668,
#   'degreeType': 'Bachelors',
#   'major': 'Paper Science',
#   'earlyCareerMedianPay': 84900,
#   'midCareerMedianPay': 136500,
#   'fiveToTenYearMedianPay': 107600,
#   'tenToTwentyYearMedianPay': 127700,
#   'twentyPlusYearMedianPay': 148200,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Paper_Science/Salary',
#   'rank': 56,
#   'tie': True},
#  {'id': 5669,
#   'degreeType': 'Bachelors',
#   'major': 'Physician Assistant Studies',
#   'earlyCareerMedianPay': 109600,
#   'midCareerMedianPay': 136500,
#   'fiveToTenYearMedianPay': 133200,
#   'tenToTwentyYearMedianPay': 136500,
#   'twentyPlusYearMedianPay': 136800,
#   'percentHighMeaning': 0.83,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Physician_Assistant_Studies/Salary',
#   'rank': 56,
#   'tie': True},
#  {'id': 5670,
#   'degreeType': 'Bachelors',
#   'major': 'Materials Science',
#   'earlyCareerMedianPay': 76700,
#   'midCareerMedianPay': 136200,
#   'fiveToTenYearMedianPay': 110700,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Materials_Science/Salary',
#   'rank': 58,
#   'tie': False},
#  {'id': 5671,
#   'degreeType': 'Bachelors',
#   'major': 'Engineering',
#   'earlyCareerMedianPay': 77800,
#   'midCareerMedianPay': 135800,
#   'fiveToTenYearMedianPay': 100600,
#   'tenToTwentyYearMedianPay': 125400,
#   'twentyPlusYearMedianPay': 148400,
#   'percentHighMeaning': 0.58,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Engineering/Salary',
#   'rank': 59,
#   'tie': False},
#  {'id': 5672,
#   'degreeType': 'Bachelors',
#   'major': 'Industrial & Systems Engineering',
#   'earlyCareerMedianPay': 82000,
#   'midCareerMedianPay': 135700,
#   'fiveToTenYearMedianPay': 105000,
#   'tenToTwentyYearMedianPay': 130700,
#   'twentyPlusYearMedianPay': 154300,
#   'percentHighMeaning': 0.48,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Industrial_%26_Systems_Engineering/Salary',
#   'rank': 60,
#   'tie': False},
#  {'id': 5673,
#   'degreeType': 'Bachelors',
#   'major': 'Metallurgical Engineering',
#   'earlyCareerMedianPay': 90800,
#   'midCareerMedianPay': 135500,
#   'fiveToTenYearMedianPay': 101100,
#   'tenToTwentyYearMedianPay': 121900,
#   'twentyPlusYearMedianPay': 146700,
#   'percentHighMeaning': 0.63,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Metallurgical_Engineering/Salary',
#   'rank': 61,
#   'tie': False},
#  {'id': 5674,
#   'degreeType': 'Bachelors',
#   'major': 'Materials Science & Engineering',
#   'earlyCareerMedianPay': 81200,
#   'midCareerMedianPay': 135300,
#   'fiveToTenYearMedianPay': 101000,
#   'tenToTwentyYearMedianPay': 127900,
#   'twentyPlusYearMedianPay': 148300,
#   'percentHighMeaning': 0.47,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Materials_Science_%26_Engineering/Salary',
#   'rank': 62,
#   'tie': False},
#  {'id': 5675,
#   'degreeType': 'Bachelors',
#   'major': 'Mining Engineering',
#   'earlyCareerMedianPay': 87400,
#   'midCareerMedianPay': 135200,
#   'fiveToTenYearMedianPay': 107600,
#   'tenToTwentyYearMedianPay': 126500,
#   'twentyPlusYearMedianPay': 151600,
#   'percentHighMeaning': 0.59,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mining_Engineering/Salary',
#   'rank': 63,
#   'tie': False},
#  {'id': 5676,
#   'degreeType': 'Bachelors',
#   'major': 'Operations Management & Information Systems',
#   'earlyCareerMedianPay': 75900,
#   'midCareerMedianPay': 134900,
#   'fiveToTenYearMedianPay': 94700,
#   'tenToTwentyYearMedianPay': 132700,
#   'twentyPlusYearMedianPay': 167000,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Operations_Management_%26_Information_Systems/Salary',
#   'rank': 64,
#   'tie': False},
#  {'id': 5677,
#   'degreeType': 'Bachelors',
#   'major': 'Business & Information Technology (IT)',
#   'earlyCareerMedianPay': 71400,
#   'midCareerMedianPay': 134700,
#   'fiveToTenYearMedianPay': 84700,
#   'tenToTwentyYearMedianPay': 123800,
#   'twentyPlusYearMedianPay': 156500,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Business_%26_Information_Technology_(IT)/Salary',
#   'rank': 65,
#   'tie': False},
#  {'id': 5678,
#   'degreeType': 'Bachelors',
#   'major': 'Interactive Media Design',
#   'earlyCareerMedianPay': 59600,
#   'midCareerMedianPay': 134400,
#   'fiveToTenYearMedianPay': 81100,
#   'tenToTwentyYearMedianPay': 130200,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.33,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Interactive_Media_Design/Salary',
#   'rank': 66,
#   'tie': False},
#  {'id': 5679,
#   'degreeType': 'Bachelors',
#   'major': 'Energy Management',
#   'earlyCareerMedianPay': 70100,
#   'midCareerMedianPay': 134100,
#   'fiveToTenYearMedianPay': 92300,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.66,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Energy_Management/Salary',
#   'rank': 67,
#   'tie': True},
#  {'id': 5680,
#   'degreeType': 'Bachelors',
#   'major': 'Physics',
#   'earlyCareerMedianPay': 75500,
#   'midCareerMedianPay': 134100,
#   'fiveToTenYearMedianPay': 97800,
#   'tenToTwentyYearMedianPay': 124800,
#   'twentyPlusYearMedianPay': 152000,
#   'percentHighMeaning': 0.49,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Physics/Salary',
#   'rank': 67,
#   'tie': True},
#  {'id': 5681,
#   'degreeType': 'Bachelors',
#   'major': 'Materials Engineering',
#   'earlyCareerMedianPay': 81200,
#   'midCareerMedianPay': 133900,
#   'fiveToTenYearMedianPay': 106800,
#   'tenToTwentyYearMedianPay': 124000,
#   'twentyPlusYearMedianPay': 152800,
#   'percentHighMeaning': 0.58,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Materials_Engineering/Salary',
#   'rank': 69,
#   'tie': False},
#  {'id': 5682,
#   'degreeType': 'Bachelors',
#   'major': 'Biomedical Engineering (BME)',
#   'earlyCareerMedianPay': 80300,
#   'midCareerMedianPay': 133500,
#   'fiveToTenYearMedianPay': 108800,
#   'tenToTwentyYearMedianPay': 130500,
#   'twentyPlusYearMedianPay': 170000,
#   'percentHighMeaning': 0.71,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Biomedical_Engineering_(BME)/Salary',
#   'rank': 70,
#   'tie': False},
#  {'id': 5683,
#   'degreeType': 'Bachelors',
#   'major': 'Industrial Engineering (IE)',
#   'earlyCareerMedianPay': 80500,
#   'midCareerMedianPay': 133400,
#   'fiveToTenYearMedianPay': 102200,
#   'tenToTwentyYearMedianPay': 127500,
#   'twentyPlusYearMedianPay': 144700,
#   'percentHighMeaning': 0.44,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Industrial_Engineering_(IE)/Salary',
#   'rank': 71,
#   'tie': True},
#  {'id': 5684,
#   'degreeType': 'Bachelors',
#   'major': 'Software Engineering',
#   'earlyCareerMedianPay': 84200,
#   'midCareerMedianPay': 133400,
#   'fiveToTenYearMedianPay': 108300,
#   'tenToTwentyYearMedianPay': 129200,
#   'twentyPlusYearMedianPay': 157000,
#   'percentHighMeaning': 0.45,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Software_Engineering/Salary',
#   'rank': 71,
#   'tie': True},
#  {'id': 5663,
#   'degreeType': 'Bachelors',
#   'major': 'Global & International Studies',
#   'earlyCareerMedianPay': 59400,
#   'midCareerMedianPay': 133300,
#   'fiveToTenYearMedianPay': 74400,
#   'tenToTwentyYearMedianPay': 133300,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.55,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Global_%26_International_Studies/Salary',
#   'rank': 73,
#   'tie': False},
#  {'id': 5685,
#   'degreeType': 'Bachelors',
#   'major': 'Computer & Information Science',
#   'earlyCareerMedianPay': 72600,
#   'midCareerMedianPay': 133100,
#   'fiveToTenYearMedianPay': 99900,
#   'tenToTwentyYearMedianPay': 127300,
#   'twentyPlusYearMedianPay': 144600,
#   'percentHighMeaning': 0.58,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Computer_%26_Information_Science/Salary',
#   'rank': 74,
#   'tie': False},
#  {'id': 5662,
#   'degreeType': 'Bachelors',
#   'major': 'Aeronautical/Aerospace Engineering Technology',
#   'earlyCareerMedianPay': 82400,
#   'midCareerMedianPay': 132800,
#   'fiveToTenYearMedianPay': 105100,
#   'tenToTwentyYearMedianPay': 124000,
#   'twentyPlusYearMedianPay': 144300,
#   'percentHighMeaning': 0.51,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Aeronautical%2FAerospace_Engineering_Technology/Salary',
#   'rank': 75,
#   'tie': False},
#  {'id': 5660,
#   'degreeType': 'Bachelors',
#   'major': 'Economics and Mathematics',
#   'earlyCareerMedianPay': 77100,
#   'midCareerMedianPay': 132700,
#   'fiveToTenYearMedianPay': 118300,
#   'tenToTwentyYearMedianPay': 132700,
#   'twentyPlusYearMedianPay': 136500,
#   'percentHighMeaning': 0.38,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Economics_and_Mathematics/Salary',
#   'rank': 76,
#   'tie': True},
#  {'id': 5639,
#   'degreeType': 'Bachelors',
#   'major': 'Industrial Hygiene',
#   'earlyCareerMedianPay': 65100,
#   'midCareerMedianPay': 132700,
#   'fiveToTenYearMedianPay': 105100,
#   'tenToTwentyYearMedianPay': 130200,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Industrial_Hygiene/Salary',
#   'rank': 76,
#   'tie': True},
#  {'id': 5640,
#   'degreeType': 'Bachelors',
#   'major': 'Engineering Mechanics',
#   'earlyCareerMedianPay': 82800,
#   'midCareerMedianPay': 131900,
#   'fiveToTenYearMedianPay': 111900,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Engineering_Mechanics/Salary',
#   'rank': 78,
#   'tie': False},
#  {'id': 5641,
#   'degreeType': 'Bachelors',
#   'major': 'Business & Economics',
#   'earlyCareerMedianPay': 66500,
#   'midCareerMedianPay': 131700,
#   'fiveToTenYearMedianPay': 99100,
#   'tenToTwentyYearMedianPay': 123900,
#   'twentyPlusYearMedianPay': 142000,
#   'percentHighMeaning': 0.44,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Business_%26_Economics/Salary',
#   'rank': 79,
#   'tie': False},
#  {'id': 5642,
#   'degreeType': 'Bachelors',
#   'major': 'Astrophysics',
#   'earlyCareerMedianPay': 78600,
#   'midCareerMedianPay': 131200,
#   'fiveToTenYearMedianPay': 95500,
#   'tenToTwentyYearMedianPay': 123800,
#   'twentyPlusYearMedianPay': 155100,
#   'percentHighMeaning': 0.61,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Astrophysics/Salary',
#   'rank': 80,
#   'tie': False},
#  {'id': 5643,
#   'degreeType': 'Bachelors',
#   'major': 'Electronics Engineering',
#   'earlyCareerMedianPay': 77700,
#   'midCareerMedianPay': 130900,
#   'fiveToTenYearMedianPay': 87600,
#   'tenToTwentyYearMedianPay': 120400,
#   'twentyPlusYearMedianPay': 137600,
#   'percentHighMeaning': 0.65,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Electronics_Engineering/Salary',
#   'rank': 81,
#   'tie': True},
#  {'id': 5644,
#   'degreeType': 'Bachelors',
#   'major': 'Telecommunications Engineering',
#   'earlyCareerMedianPay': 78000,
#   'midCareerMedianPay': 130900,
#   'fiveToTenYearMedianPay': 93900,
#   'tenToTwentyYearMedianPay': 148800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Telecommunications_Engineering/Salary',
#   'rank': 81,
#   'tie': True},
#  {'id': 5645,
#   'degreeType': 'Bachelors',
#   'major': 'International Business & Finance',
#   'earlyCareerMedianPay': 69000,
#   'midCareerMedianPay': 130800,
#   'fiveToTenYearMedianPay': 98000,
#   'tenToTwentyYearMedianPay': 130800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.3,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_International_Business_%26_Finance/Salary',
#   'rank': 83,
#   'tie': False},
#  {'id': 5646,
#   'degreeType': 'Bachelors',
#   'major': 'International Economics',
#   'earlyCareerMedianPay': 66200,
#   'midCareerMedianPay': 130600,
#   'fiveToTenYearMedianPay': 102500,
#   'tenToTwentyYearMedianPay': 129400,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_International_Economics/Salary',
#   'rank': 84,
#   'tie': False},
#  {'id': 5647,
#   'degreeType': 'Bachelors',
#   'major': 'Business Analysis',
#   'earlyCareerMedianPay': 71000,
#   'midCareerMedianPay': 130300,
#   'fiveToTenYearMedianPay': 81300,
#   'tenToTwentyYearMedianPay': 97700,
#   'twentyPlusYearMedianPay': 177100,
#   'percentHighMeaning': 0.47,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Business_Analysis/Salary',
#   'rank': 85,
#   'tie': True},
#  {'id': 5648,
#   'degreeType': 'Bachelors',
#   'major': 'Management Science',
#   'earlyCareerMedianPay': 73000,
#   'midCareerMedianPay': 130300,
#   'fiveToTenYearMedianPay': 109200,
#   'tenToTwentyYearMedianPay': 116800,
#   'twentyPlusYearMedianPay': 146600,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Management_Science/Salary',
#   'rank': 85,
#   'tie': True},
#  {'id': 5649,
#   'degreeType': 'Bachelors',
#   'major': 'Mechanical Engineering (ME)',
#   'earlyCareerMedianPay': 79600,
#   'midCareerMedianPay': 130300,
#   'fiveToTenYearMedianPay': 99900,
#   'tenToTwentyYearMedianPay': 123600,
#   'twentyPlusYearMedianPay': 147300,
#   'percentHighMeaning': 0.49,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mechanical_Engineering_(ME)/Salary',
#   'rank': 85,
#   'tie': True},
#  {'id': 5650,
#   'degreeType': 'Bachelors',
#   'major': 'Economics',
#   'earlyCareerMedianPay': 70500,
#   'midCareerMedianPay': 130200,
#   'fiveToTenYearMedianPay': 101400,
#   'tenToTwentyYearMedianPay': 125100,
#   'twentyPlusYearMedianPay': 143400,
#   'percentHighMeaning': 0.41,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Economics/Salary',
#   'rank': 88,
#   'tie': False},
#  {'id': 5651,
#   'degreeType': 'Bachelors',
#   'major': 'Ceramic Engineering',
#   'earlyCareerMedianPay': 76400,
#   'midCareerMedianPay': 129900,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': 113100,
#   'twentyPlusYearMedianPay': 138300,
#   'percentHighMeaning': 0.46,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Ceramic_Engineering/Salary',
#   'rank': 89,
#   'tie': False},
#  {'id': 5652,
#   'degreeType': 'Bachelors',
#   'major': 'Management Information Systems (MIS)',
#   'earlyCareerMedianPay': 73900,
#   'midCareerMedianPay': 129500,
#   'fiveToTenYearMedianPay': 99800,
#   'tenToTwentyYearMedianPay': 123100,
#   'twentyPlusYearMedianPay': 146600,
#   'percentHighMeaning': 0.42,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Management_Information_Systems_(MIS)/Salary',
#   'rank': 90,
#   'tie': False},
#  {'id': 5653,
#   'degreeType': 'Bachelors',
#   'major': 'Industrial Distribution',
#   'earlyCareerMedianPay': 71400,
#   'midCareerMedianPay': 129200,
#   'fiveToTenYearMedianPay': 89500,
#   'tenToTwentyYearMedianPay': 111800,
#   'twentyPlusYearMedianPay': 147000,
#   'percentHighMeaning': 0.48,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Industrial_Distribution/Salary',
#   'rank': 91,
#   'tie': False},
#  {'id': 5654,
#   'degreeType': 'Bachelors',
#   'major': 'Structural Engineering (SE)',
#   'earlyCareerMedianPay': 76200,
#   'midCareerMedianPay': 128900,
#   'fiveToTenYearMedianPay': 93100,
#   'tenToTwentyYearMedianPay': 116700,
#   'twentyPlusYearMedianPay': 143400,
#   'percentHighMeaning': 0.67,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Structural_Engineering_(SE)/Salary',
#   'rank': 92,
#   'tie': False},
#  {'id': 5655,
#   'degreeType': 'Bachelors',
#   'major': 'Accounting & Taxation',
#   'earlyCareerMedianPay': 61900,
#   'midCareerMedianPay': 128600,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': 130600,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Accounting_%26_Taxation/Salary',
#   'rank': 93,
#   'tie': False},
#  {'id': 5656,
#   'degreeType': 'Bachelors',
#   'major': 'Integrated Science & Technology',
#   'earlyCareerMedianPay': 71600,
#   'midCareerMedianPay': 128400,
#   'fiveToTenYearMedianPay': 100300,
#   'tenToTwentyYearMedianPay': 126100,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.55,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Integrated_Science_%26_Technology/Salary',
#   'rank': 94,
#   'tie': False},
#  {'id': 5657,
#   'degreeType': 'Bachelors',
#   'major': 'Automotive Engineering',
#   'earlyCareerMedianPay': 75700,
#   'midCareerMedianPay': 128300,
#   'fiveToTenYearMedianPay': 90100,
#   'tenToTwentyYearMedianPay': 118700,
#   'twentyPlusYearMedianPay': 135100,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Automotive_Engineering/Salary',
#   'rank': 95,
#   'tie': False},
#  {'id': 5658,
#   'degreeType': 'Bachelors',
#   'major': 'Mathematics & Statistics',
#   'earlyCareerMedianPay': 71800,
#   'midCareerMedianPay': 128100,
#   'fiveToTenYearMedianPay': 95300,
#   'tenToTwentyYearMedianPay': 119800,
#   'twentyPlusYearMedianPay': 151900,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mathematics_%26_Statistics/Salary',
#   'rank': 96,
#   'tie': False},
#  {'id': 5659,
#   'degreeType': 'Bachelors',
#   'major': 'Packaging Science',
#   'earlyCareerMedianPay': 78600,
#   'midCareerMedianPay': 127600,
#   'fiveToTenYearMedianPay': 99700,
#   'tenToTwentyYearMedianPay': 116100,
#   'twentyPlusYearMedianPay': 137100,
#   'percentHighMeaning': 0.41,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Packaging_Science/Salary',
#   'rank': 97,
#   'tie': False},
#  {'id': 5588,
#   'degreeType': 'Bachelors',
#   'major': 'Construction Project Management',
#   'earlyCareerMedianPay': 69400,
#   'midCareerMedianPay': 127400,
#   'fiveToTenYearMedianPay': 89200,
#   'tenToTwentyYearMedianPay': 111100,
#   'twentyPlusYearMedianPay': 142500,
#   'percentHighMeaning': 0.64,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Construction_Project_Management/Salary',
#   'rank': 98,
#   'tie': False},
#  {'id': 5636,
#   'degreeType': 'Bachelors',
#   'major': 'Plastics Engineering',
#   'earlyCareerMedianPay': 79200,
#   'midCareerMedianPay': 127200,
#   'fiveToTenYearMedianPay': 97200,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': 126600,
#   'percentHighMeaning': 0.58,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Plastics_Engineering/Salary',
#   'rank': 99,
#   'tie': False},
#  {'id': 5587,
#   'degreeType': 'Bachelors',
#   'major': 'Information & Decision Sciences',
#   'earlyCareerMedianPay': 73200,
#   'midCareerMedianPay': 126800,
#   'fiveToTenYearMedianPay': 105700,
#   'tenToTwentyYearMedianPay': 122000,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.36,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Information_%26_Decision_Sciences/Salary',
#   'rank': 100,
#   'tie': False},
#  {'id': 5536,
#   'degreeType': 'Bachelors',
#   'major': 'Applied Physics',
#   'earlyCareerMedianPay': 75800,
#   'midCareerMedianPay': 126500,
#   'fiveToTenYearMedianPay': 103200,
#   'tenToTwentyYearMedianPay': 124700,
#   'twentyPlusYearMedianPay': 133600,
#   'percentHighMeaning': 0.53,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Applied_Physics/Salary',
#   'rank': 101,
#   'tie': False},
#  {'id': 5514,
#   'degreeType': 'Bachelors',
#   'major': 'Building Construction (BC)',
#   'earlyCareerMedianPay': 73200,
#   'midCareerMedianPay': 125900,
#   'fiveToTenYearMedianPay': 95200,
#   'tenToTwentyYearMedianPay': 122400,
#   'twentyPlusYearMedianPay': 132200,
#   'percentHighMeaning': 0.51,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Building_Construction_(BC)/Salary',
#   'rank': 102,
#   'tie': True},
#  {'id': 5515,
#   'degreeType': 'Bachelors',
#   'major': 'Petroleum Land Management',
#   'earlyCareerMedianPay': 66600,
#   'midCareerMedianPay': 125900,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Petroleum_Land_Management/Salary',
#   'rank': 102,
#   'tie': True},
#  {'id': 5516,
#   'degreeType': 'Bachelors',
#   'major': 'Industrial Engineering & Management',
#   'earlyCareerMedianPay': 74800,
#   'midCareerMedianPay': 125700,
#   'fiveToTenYearMedianPay': 102200,
#   'tenToTwentyYearMedianPay': 125700,
#   'twentyPlusYearMedianPay': 126000,
#   'percentHighMeaning': 0.54,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Industrial_Engineering_%26_Management/Salary',
#   'rank': 104,
#   'tie': False},
#  {'id': 5517,
#   'degreeType': 'Bachelors',
#   'major': 'Accounting & Economics',
#   'earlyCareerMedianPay': 74500,
#   'midCareerMedianPay': 125400,
#   'fiveToTenYearMedianPay': 101100,
#   'tenToTwentyYearMedianPay': 111400,
#   'twentyPlusYearMedianPay': 151300,
#   'percentHighMeaning': 0.48,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Accounting_%26_Economics/Salary',
#   'rank': 105,
#   'tie': True},
#  {'id': 5518,
#   'degreeType': 'Bachelors',
#   'major': 'Psychobiology',
#   'earlyCareerMedianPay': 58600,
#   'midCareerMedianPay': 125400,
#   'fiveToTenYearMedianPay': 85800,
#   'tenToTwentyYearMedianPay': 115200,
#   'twentyPlusYearMedianPay': 135700,
#   'percentHighMeaning': 0.69,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Psychobiology/Salary',
#   'rank': 105,
#   'tie': True},
#  {'id': 5519,
#   'degreeType': 'Bachelors',
#   'major': 'Finance & Economics',
#   'earlyCareerMedianPay': 70300,
#   'midCareerMedianPay': 124800,
#   'fiveToTenYearMedianPay': 101400,
#   'tenToTwentyYearMedianPay': 117700,
#   'twentyPlusYearMedianPay': 137500,
#   'percentHighMeaning': 0.42,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Finance_%26_Economics/Salary',
#   'rank': 107,
#   'tie': False},
#  {'id': 5520,
#   'degreeType': 'Bachelors',
#   'major': 'Medicine',
#   'earlyCareerMedianPay': 88700,
#   'midCareerMedianPay': 124700,
#   'fiveToTenYearMedianPay': 99500,
#   'tenToTwentyYearMedianPay': 124000,
#   'twentyPlusYearMedianPay': 126200,
#   'percentHighMeaning': 0.94,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Medicine/Salary',
#   'rank': 108,
#   'tie': False},
#  {'id': 5521,
#   'degreeType': 'Bachelors',
#   'major': 'Asian Studies',
#   'earlyCareerMedianPay': 53100,
#   'midCareerMedianPay': 123800,
#   'fiveToTenYearMedianPay': 77500,
#   'tenToTwentyYearMedianPay': 125600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.43,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Asian_Studies/Salary',
#   'rank': 109,
#   'tie': False},
#  {'id': 5522,
#   'degreeType': 'Bachelors',
#   'major': 'Marketing & International Business',
#   'earlyCareerMedianPay': 59600,
#   'midCareerMedianPay': 123500,
#   'fiveToTenYearMedianPay': 85200,
#   'tenToTwentyYearMedianPay': 121800,
#   'twentyPlusYearMedianPay': 138200,
#   'percentHighMeaning': 0.36,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Marketing_%26_International_Business/Salary',
#   'rank': 110,
#   'tie': False},
#  {'id': 5523,
#   'degreeType': 'Bachelors',
#   'major': 'Government',
#   'earlyCareerMedianPay': 63500,
#   'midCareerMedianPay': 123400,
#   'fiveToTenYearMedianPay': 88700,
#   'tenToTwentyYearMedianPay': 117400,
#   'twentyPlusYearMedianPay': 134100,
#   'percentHighMeaning': 0.45,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Government/Salary',
#   'rank': 111,
#   'tie': False},
#  {'id': 5524,
#   'degreeType': 'Bachelors',
#   'major': 'Business Computer Information Systems (BCIS)',
#   'earlyCareerMedianPay': 74200,
#   'midCareerMedianPay': 123300,
#   'fiveToTenYearMedianPay': 89700,
#   'tenToTwentyYearMedianPay': 107600,
#   'twentyPlusYearMedianPay': 149000,
#   'percentHighMeaning': 0.4,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Business_Computer_Information_Systems_(BCIS)/Salary',
#   'rank': 112,
#   'tie': True},
#  {'id': 5525,
#   'degreeType': 'Bachelors',
#   'major': 'Finance & Real Estate',
#   'earlyCareerMedianPay': 73500,
#   'midCareerMedianPay': 123300,
#   'fiveToTenYearMedianPay': 93700,
#   'tenToTwentyYearMedianPay': 120000,
#   'twentyPlusYearMedianPay': 134400,
#   'percentHighMeaning': 0.42,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Finance_%26_Real_Estate/Salary',
#   'rank': 112,
#   'tie': True},
#  {'id': 5526,
#   'degreeType': 'Bachelors',
#   'major': 'Biochemistry & Molecular Biology',
#   'earlyCareerMedianPay': 61700,
#   'midCareerMedianPay': 123100,
#   'fiveToTenYearMedianPay': 83600,
#   'tenToTwentyYearMedianPay': 116700,
#   'twentyPlusYearMedianPay': 155300,
#   'percentHighMeaning': 0.7,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Biochemistry_%26_Molecular_Biology/Salary',
#   'rank': 114,
#   'tie': True},
#  {'id': 5527,
# ...
#   'degreeType': 'Bachelors',
#   'major': 'Bible Studies & Theology',
#   'earlyCareerMedianPay': 44800,
#   'midCareerMedianPay': 65100,
#   'fiveToTenYearMedianPay': 55700,
#   'tenToTwentyYearMedianPay': 64500,
#   'twentyPlusYearMedianPay': 67500,
#   'percentHighMeaning': 0.68,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Bible_Studies_%26_Theology/Salary',
#   'rank': 761,
#   'tie': False},
#  {'id': 5374,
#   'degreeType': 'Bachelors',
#   'major': 'Biblical Studies',
#   'earlyCareerMedianPay': 47000,
#   'midCareerMedianPay': 65000,
#   'fiveToTenYearMedianPay': 52300,
#   'tenToTwentyYearMedianPay': 60500,
#   'twentyPlusYearMedianPay': 74300,
#   'percentHighMeaning': 0.71,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Biblical_Studies/Salary',
#   'rank': 762,
#   'tie': False},
#  {'id': 5375,
#   'degreeType': 'Bachelors',
#   'major': 'Christian Ministry',
#   'earlyCareerMedianPay': 43000,
#   'midCareerMedianPay': 64500,
#   'fiveToTenYearMedianPay': 52900,
#   'tenToTwentyYearMedianPay': 59200,
#   'twentyPlusYearMedianPay': 79800,
#   'percentHighMeaning': 0.75,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Christian_Ministry/Salary',
#   'rank': 763,
#   'tie': False},
#  {'id': 5376,
#   'degreeType': 'Bachelors',
#   'major': 'Human Development & Family Studies',
#   'earlyCareerMedianPay': 45400,
#   'midCareerMedianPay': 64400,
#   'fiveToTenYearMedianPay': 55100,
#   'tenToTwentyYearMedianPay': 61900,
#   'twentyPlusYearMedianPay': 71300,
#   'percentHighMeaning': 0.63,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Human_Development_%26_Family_Studies/Salary',
#   'rank': 764,
#   'tie': False},
#  {'id': 5377,
#   'degreeType': 'Bachelors',
#   'major': 'Church Ministries',
#   'earlyCareerMedianPay': 43600,
#   'midCareerMedianPay': 64300,
#   'fiveToTenYearMedianPay': 55200,
#   'tenToTwentyYearMedianPay': 61300,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.79,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Church_Ministries/Salary',
#   'rank': 765,
#   'tie': False},
#  {'id': 5378,
#   'degreeType': 'Bachelors',
#   'major': 'Community Development',
#   'earlyCareerMedianPay': 50300,
#   'midCareerMedianPay': 63600,
#   'fiveToTenYearMedianPay': 60200,
#   'tenToTwentyYearMedianPay': 61200,
#   'twentyPlusYearMedianPay': 65800,
#   'percentHighMeaning': 0.69,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Community_Development/Salary',
#   'rank': 766,
#   'tie': False},
#  {'id': 5379,
#   'degreeType': 'Bachelors',
#   'major': 'Music Therapy',
#   'earlyCareerMedianPay': 48500,
#   'midCareerMedianPay': 63500,
#   'fiveToTenYearMedianPay': 49500,
#   'tenToTwentyYearMedianPay': 61900,
#   'twentyPlusYearMedianPay': 64100,
#   'percentHighMeaning': 0.95,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Music_Therapy/Salary',
#   'rank': 767,
#   'tie': False},
#  {'id': 5380,
#   'degreeType': 'Bachelors',
#   'major': 'Voice & Opera',
#   'earlyCareerMedianPay': 38700,
#   'midCareerMedianPay': 63200,
#   'fiveToTenYearMedianPay': 56600,
#   'tenToTwentyYearMedianPay': 71500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.53,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Voice_%26_Opera/Salary',
#   'rank': 768,
#   'tie': False},
#  {'id': 5381,
#   'degreeType': 'Bachelors',
#   'major': 'Legal Assistant Studies',
#   'earlyCareerMedianPay': 42000,
#   'midCareerMedianPay': 63000,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': 62900,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.39,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Legal_Assistant_Studies/Salary',
#   'rank': 769,
#   'tie': False},
#  {'id': 5382,
#   'degreeType': 'Bachelors',
#   'major': 'Health and Human Services',
#   'earlyCareerMedianPay': 48800,
#   'midCareerMedianPay': 62900,
#   'fiveToTenYearMedianPay': 52400,
#   'tenToTwentyYearMedianPay': 61500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.64,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Health_and_Human_Services/Salary',
#   'rank': 770,
#   'tie': False},
#  {'id': 5383,
#   'degreeType': 'Bachelors',
#   'major': 'Home Economics',
#   'earlyCareerMedianPay': 47700,
#   'midCareerMedianPay': 62800,
#   'fiveToTenYearMedianPay': 56100,
#   'tenToTwentyYearMedianPay': 62400,
#   'twentyPlusYearMedianPay': 63000,
#   'percentHighMeaning': 0.69,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Home_Economics/Salary',
#   'rank': 771,
#   'tie': False},
#  {'id': 5384,
#   'degreeType': 'Bachelors',
#   'major': 'Special Education',
#   'earlyCareerMedianPay': 46400,
#   'midCareerMedianPay': 62700,
#   'fiveToTenYearMedianPay': 50700,
#   'tenToTwentyYearMedianPay': 56000,
#   'twentyPlusYearMedianPay': 70300,
#   'percentHighMeaning': 0.75,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Special_Education/Salary',
#   'rank': 772,
#   'tie': False},
#  {'id': 5363,
#   'degreeType': 'Bachelors',
#   'major': 'Conflict Resolution',
#   'earlyCareerMedianPay': 52000,
#   'midCareerMedianPay': 62100,
#   'fiveToTenYearMedianPay': 63200,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Conflict_Resolution/Salary',
#   'rank': 773,
#   'tie': False},
#  {'id': 5362,
#   'degreeType': 'Bachelors',
#   'major': 'Educational Psychology',
#   'earlyCareerMedianPay': 45900,
#   'midCareerMedianPay': 61800,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Educational_Psychology/Salary',
#   'rank': 774,
#   'tie': True},
#  {'id': 5385,
#   'degreeType': 'Bachelors',
#   'major': 'Developmental Psychology',
#   'earlyCareerMedianPay': 42900,
#   'midCareerMedianPay': 61800,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Developmental_Psychology/Salary',
#   'rank': 774,
#   'tie': True},
#  {'id': 5360,
#   'degreeType': 'Bachelors',
#   'major': 'Youth Ministry',
#   'earlyCareerMedianPay': 42800,
#   'midCareerMedianPay': 61700,
#   'fiveToTenYearMedianPay': 48700,
#   'tenToTwentyYearMedianPay': 61400,
#   'twentyPlusYearMedianPay': 74400,
#   'percentHighMeaning': 0.74,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Youth_Ministry/Salary',
#   'rank': 776,
#   'tie': False},
#  {'id': 5339,
#   'degreeType': 'Bachelors',
#   'major': 'Therapeutic Recreation',
#   'earlyCareerMedianPay': 44900,
#   'midCareerMedianPay': 61500,
#   'fiveToTenYearMedianPay': 51400,
#   'tenToTwentyYearMedianPay': 59000,
#   'twentyPlusYearMedianPay': 65800,
#   'percentHighMeaning': 0.83,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Therapeutic_Recreation/Salary',
#   'rank': 777,
#   'tie': False},
#  {'id': 5340,
#   'degreeType': 'Bachelors',
#   'major': 'Community & Human Services',
#   'earlyCareerMedianPay': 48100,
#   'midCareerMedianPay': 61300,
#   'fiveToTenYearMedianPay': 51900,
#   'tenToTwentyYearMedianPay': 57300,
#   'twentyPlusYearMedianPay': 62400,
#   'percentHighMeaning': 0.79,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Community_%26_Human_Services/Salary',
#   'rank': 778,
#   'tie': True},
#  {'id': 5341,
#   'degreeType': 'Bachelors',
#   'major': 'Social Work (SW)',
#   'earlyCareerMedianPay': 43300,
#   'midCareerMedianPay': 61300,
#   'fiveToTenYearMedianPay': 51500,
#   'tenToTwentyYearMedianPay': 57900,
#   'twentyPlusYearMedianPay': 67100,
#   'percentHighMeaning': 0.76,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Social_Work_(SW)/Salary',
#   'rank': 778,
#   'tie': True},
#  {'id': 5342,
#   'degreeType': 'Bachelors',
#   'major': 'Elementary Education',
#   'earlyCareerMedianPay': 45800,
#   'midCareerMedianPay': 60700,
#   'fiveToTenYearMedianPay': 50900,
#   'tenToTwentyYearMedianPay': 57000,
#   'twentyPlusYearMedianPay': 67100,
#   'percentHighMeaning': 0.68,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Elementary_Education/Salary',
#   'rank': 780,
#   'tie': False},
#  {'id': 5343,
#   'degreeType': 'Bachelors',
#   'major': 'Office Administration',
#   'earlyCareerMedianPay': 43400,
#   'midCareerMedianPay': 60500,
#   'fiveToTenYearMedianPay': 53800,
#   'tenToTwentyYearMedianPay': 58200,
#   'twentyPlusYearMedianPay': 65400,
#   'percentHighMeaning': 0.67,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Office_Administration/Salary',
#   'rank': 781,
#   'tie': False},
#  {'id': 5344,
#   'degreeType': 'Bachelors',
#   'major': 'Christian Education',
#   'earlyCareerMedianPay': 45300,
#   'midCareerMedianPay': 60300,
#   'fiveToTenYearMedianPay': 50300,
#   'tenToTwentyYearMedianPay': 53600,
#   'twentyPlusYearMedianPay': 60500,
#   'percentHighMeaning': 0.84,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Christian_Education/Salary',
#   'rank': 782,
#   'tie': False},
#  {'id': 5345,
#   'degreeType': 'Bachelors',
#   'major': 'Counseling',
#   'earlyCareerMedianPay': 45100,
#   'midCareerMedianPay': 59600,
#   'fiveToTenYearMedianPay': 50500,
#   'tenToTwentyYearMedianPay': 59300,
#   'twentyPlusYearMedianPay': 60300,
#   'percentHighMeaning': 0.79,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Counseling/Salary',
#   'rank': 783,
#   'tie': True},
#  {'id': 5346,
#   'degreeType': 'Bachelors',
#   'major': 'Human Services (HS)',
#   'earlyCareerMedianPay': 44400,
#   'midCareerMedianPay': 59600,
#   'fiveToTenYearMedianPay': 50700,
#   'tenToTwentyYearMedianPay': 56900,
#   'twentyPlusYearMedianPay': 64200,
#   'percentHighMeaning': 0.7,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Human_Services_(HS)/Salary',
#   'rank': 783,
#   'tie': True},
#  {'id': 5347,
#   'degreeType': 'Bachelors',
#   'major': 'Health & Human Performance',
#   'earlyCareerMedianPay': 43000,
#   'midCareerMedianPay': 58900,
#   'fiveToTenYearMedianPay': 56400,
#   'tenToTwentyYearMedianPay': 57800,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.67,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Health_%26_Human_Performance/Salary',
#   'rank': 785,
#   'tie': False},
#  {'id': 5348,
#   'degreeType': 'Bachelors',
#   'major': 'Mental Health Counseling',
#   'earlyCareerMedianPay': 40600,
#   'midCareerMedianPay': 58500,
#   'fiveToTenYearMedianPay': 54800,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': None,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mental_Health_Counseling/Salary',
#   'rank': 786,
#   'tie': True},
#  {'id': 5349,
#   'degreeType': 'Bachelors',
#   'major': 'Middle School Education',
#   'earlyCareerMedianPay': 47200,
#   'midCareerMedianPay': 58500,
#   'fiveToTenYearMedianPay': 49800,
#   'tenToTwentyYearMedianPay': 57600,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.76,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Middle_School_Education/Salary',
#   'rank': 786,
#   'tie': True},
#  {'id': 5350,
#   'degreeType': 'Bachelors',
#   'major': 'Child Development',
#   'earlyCareerMedianPay': 42200,
#   'midCareerMedianPay': 57900,
#   'fiveToTenYearMedianPay': 46500,
#   'tenToTwentyYearMedianPay': 56700,
#   'twentyPlusYearMedianPay': 61300,
#   'percentHighMeaning': 0.73,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Child_Development/Salary',
#   'rank': 788,
#   'tie': False},
#  {'id': 5351,
#   'degreeType': 'Bachelors',
#   'major': 'Recreational Therapy',
#   'earlyCareerMedianPay': 44900,
#   'midCareerMedianPay': 57200,
#   'fiveToTenYearMedianPay': 49300,
#   'tenToTwentyYearMedianPay': 52500,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.84,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Recreational_Therapy/Salary',
#   'rank': 789,
#   'tie': False},
#  {'id': 5352,
#   'degreeType': 'Bachelors',
#   'major': 'Early Childhood & Elementary Education',
#   'earlyCareerMedianPay': 43400,
#   'midCareerMedianPay': 56500,
#   'fiveToTenYearMedianPay': 46500,
#   'tenToTwentyYearMedianPay': 54900,
#   'twentyPlusYearMedianPay': 57700,
#   'percentHighMeaning': 0.76,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Early_Childhood_%26_Elementary_Education/Salary',
#   'rank': 790,
#   'tie': False},
#  {'id': 5353,
#   'degreeType': 'Bachelors',
#   'major': 'Outdoor Education',
#   'earlyCareerMedianPay': 42200,
#   'midCareerMedianPay': 55200,
#   'fiveToTenYearMedianPay': 46300,
#   'tenToTwentyYearMedianPay': 52000,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.51,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Outdoor_Education/Salary',
#   'rank': 791,
#   'tie': False},
#  {'id': 5354,
#   'degreeType': 'Bachelors',
#   'major': 'Baking & Pastry Arts',
#   'earlyCareerMedianPay': 42400,
#   'midCareerMedianPay': 54900,
#   'fiveToTenYearMedianPay': 49700,
#   'tenToTwentyYearMedianPay': 53700,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.38,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Baking_%26_Pastry_Arts/Salary',
#   'rank': 792,
#   'tie': False},
#  {'id': 5355,
#   'degreeType': 'Bachelors',
#   'major': 'Mental Health',
#   'earlyCareerMedianPay': 42700,
#   'midCareerMedianPay': 52900,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.76,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Mental_Health/Salary',
#   'rank': 793,
#   'tie': False},
#  {'id': 5356,
#   'degreeType': 'Bachelors',
#   'major': 'Child & Family Studies',
#   'earlyCareerMedianPay': 41600,
#   'midCareerMedianPay': 52700,
#   'fiveToTenYearMedianPay': 44800,
#   'tenToTwentyYearMedianPay': 51900,
#   'twentyPlusYearMedianPay': 69500,
#   'percentHighMeaning': 0.73,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Child_%26_Family_Studies/Salary',
#   'rank': 794,
#   'tie': False},
#  {'id': 5357,
#   'degreeType': 'Bachelors',
#   'major': 'Equine Studies',
#   'earlyCareerMedianPay': 40300,
#   'midCareerMedianPay': 52500,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': 51900,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.5,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Equine_Studies/Salary',
#   'rank': 795,
#   'tie': False},
#  {'id': 5358,
#   'degreeType': 'Bachelors',
#   'major': 'Addictions Counseling',
#   'earlyCareerMedianPay': 45900,
#   'midCareerMedianPay': 52200,
#   'fiveToTenYearMedianPay': None,
#   'tenToTwentyYearMedianPay': 50300,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.78,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Addictions_Counseling/Salary',
#   'rank': 796,
#   'tie': False},
#  {'id': 5359,
#   'degreeType': 'Bachelors',
#   'major': 'Nonprofit Administration',
#   'earlyCareerMedianPay': 42800,
#   'midCareerMedianPay': 52100,
#   'fiveToTenYearMedianPay': 54500,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.72,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Nonprofit_Administration/Salary',
#   'rank': 797,
#   'tie': False},
#  {'id': 5486,
#   'degreeType': 'Bachelors',
#   'major': 'Early Childhood Education',
#   'earlyCareerMedianPay': 41700,
#   'midCareerMedianPay': 50600,
#   'fiveToTenYearMedianPay': 44300,
#   'tenToTwentyYearMedianPay': 48800,
#   'twentyPlusYearMedianPay': 54200,
#   'percentHighMeaning': 0.77,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Early_Childhood_Education/Salary',
#   'rank': 798,
#   'tie': False},
#  {'id': 5886,
#   'degreeType': 'Bachelors',
#   'major': 'Metalsmithing',
#   'earlyCareerMedianPay': 44700,
#   'midCareerMedianPay': 44900,
#   'fiveToTenYearMedianPay': 57400,
#   'tenToTwentyYearMedianPay': None,
#   'twentyPlusYearMedianPay': None,
#   'percentHighMeaning': 0.36,
#   'year': 2023,
#   'url': '/research/US/Degree=Bachelor%27s_Degree%2C_Metalsmithing/Salary',
#   'rank': 799,
#   'tie': False}]

# %%
len(l)
# Out:
# 799

# %%
df_current = pd.DataFrame(l)

# %%
#note there are some columns with nan values:
df_current.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        799 non-null    int64
#  1   degreeType                799 non-null    object
#  2   major                     799 non-null    object
#  3   earlyCareerMedianPay      799 non-null    int64
#  4   midCareerMedianPay        799 non-null    int64
#  5   fiveToTenYearMedianPay    752 non-null    float64
#  6   tenToTwentyYearMedianPay  712 non-null    float64
#  7   twentyPlusYearMedianPay   510 non-null    float64
#  8   percentHighMeaning        739 non-null    float64
#  9   year                      799 non-null    int64
#  10  url                       799 non-null    object
#  11  rank                      799 non-null    int64
#  12  tie                       799 non-null    bool
# dtypes: bool(1), float64(4), int64(5), object(3)
# memory usage: 75.8+ KB

# %% [markdown]
# ### Note that 5-10 year median salary is null for many entries, so further analysis with that column is not accurate but for the sake of getting familiar with pandas we will continue the analysis with that column.

# %%
df_current.columns
# Out:
# Index(['id', 'degreeType', 'major', 'earlyCareerMedianPay',
#        'midCareerMedianPay', 'fiveToTenYearMedianPay',
#        'tenToTwentyYearMedianPay', 'twentyPlusYearMedianPay',
#        'percentHighMeaning', 'year', 'url', 'rank', 'tie'],
#       dtype='object')

# %%
df_current.shape
# Out:
# (799, 13)

# %%
#The data set has no repeated entries:
df_current[df_current.loc[:,'major'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, degreeType, major, earlyCareerMedianPay, midCareerMedianPay, fiveToTenYearMedianPay, tenToTwentyYearMedianPay, twentyPlusYearMedianPay, percentHighMeaning, year, url, rank, tie, spread]
# Index: []

# %%
#Lets look at all the majors available in the data:
for i in df_current["major"]:
    print(i)
# Out:
# Petroleum Engineering
# Operations Research & Industrial Engineering
# Interaction Design
# Applied Economics and Management
# Building Science
# Actuarial Mathematics
# Operations Research
# Systems Engineering
# Optical Science & Engineering
# Information & Computer Science
# Aeronautics & Astronautics
# Aerospace Studies
# Pharmacy
# Cognitive Science
# Managerial Economics
# Quantitative Economics
# Econometrics
# Foreign Affairs
# Chemical Engineering
# Public Accounting
# Political Economy
# Corporate Accounting & Finance
# Actuarial Science
# Computer Engineering (CE)
# Electrical Power Engineering
# Computer Science (CS) & Engineering
# Marine Transportation Management
# Marine Engineering
# Operations & Information Systems Management
# Electrical & Computer Engineering (ECE)
# Entrepreneurship & Marketing
# Astronomy
# Mechatronics
# Computational & Applied Mathematics
# Aeronautical Engineering
# Welding Engineering
# Electrical Engineering (EE)
# Electrical & Electronics Engineering (EEE)
# Naval Architecture & Marine Engineering
# Instrumentation & Control Engineering
# Construction Engineering Management
# Computer Science (CS) & Mathematics
# Engineering Physics
# Mechanical & Aeronautical Engineering
# Chemical & Biomolecular Engineering
# Computer Science (CS)
# Jazz Studies
# Bioscience
# Information Management
# Aerospace Engineering
# Ocean Engineering (OE)
# Pharmacology
# Nuclear Engineering
# Bioengineering (BioE)
# Applied Mathematics
# Paper Science
# Physician Assistant Studies
# Materials Science
# Engineering
# Industrial & Systems Engineering
# Metallurgical Engineering
# Materials Science & Engineering
# Mining Engineering
# Operations Management & Information Systems
# Business & Information Technology (IT)
# Interactive Media Design
# Energy Management
# Physics
# Materials Engineering
# Biomedical Engineering (BME)
# Industrial Engineering (IE)
# Software Engineering
# Global & International Studies
# Computer & Information Science
# Aeronautical/Aerospace Engineering Technology
# Economics and Mathematics
# Industrial Hygiene
# Engineering Mechanics
# Business & Economics
# Astrophysics
# Electronics Engineering
# Telecommunications Engineering
# International Business & Finance
# International Economics
# Business Analysis
# Management Science
# Mechanical Engineering (ME)
# Economics
# Ceramic Engineering
# Management Information Systems (MIS)
# Industrial Distribution
# Structural Engineering (SE)
# Accounting & Taxation
# Integrated Science & Technology
# Automotive Engineering
# Mathematics & Statistics
# Packaging Science
# Construction Project Management
# Plastics Engineering
# Information & Decision Sciences
# Applied Physics
# Building Construction (BC)
# Petroleum Land Management
# Industrial Engineering & Management
# Accounting & Economics
# Psychobiology
# Finance & Economics
# Medicine
# Asian Studies
# Marketing & International Business
# Government
# Business Computer Information Systems (BCIS)
# Finance & Real Estate
# Biochemistry & Molecular Biology
# Environmental Health & Safety Management
# Financial Economics
# Business Economics
# Nuclear Engineering Technology (NET)
# Mathematics
# Civil Engineering (CE)
# Business Information Systems
# Information Systems Management
# Polymer Science & Engineering
# Information Security & Assurance
# Applied Economics
# International Management
# Political Communication
# Economics & Political Science
# Accounting & Computer Systems
# Civil & Environmental Engineering
# Construction Management
# Construction Science
# Control Engineering
# Russian Studies
# Cybersecurity
# Robotics & Automation
# Computer Management Information Systems (CMIS)
# Aeronautical Science
# Manufacturing Engineering
# Information Systems (IS)
# Engineering Management
# Computing & Information Systems (CIS)
# Mechanical
# Business Logistics & Transportation
# Biosystems Engineering
# Agricultural Economics
# Data Processing
# Food Marketing
# Geophysics
# Management & Finance
# Business Finance
# Construction Engineering
# Organic Chemistry
# Real Estate
# Finance
# Plastics Engineering Technology
# European Studies
# Safety Science
# Computer Science & Information Technology
# Japanese Language
# Information Sciences and Technology
# International Business
# Architectural Engineering
# International Marketing
# Molecular Biology
# Building Construction Management
# Business Operations
# Computer Information Systems (CIS)
# Electrical Engineering Technology (EET)
# Government & International Politics (GVIP)
# Information Security
# East Asian Studies
# Strategic Management
# Labor Relations
# Entrepreneurship & Leadership
# Agricultural Engineering (AE)
# Information Technology Management
# International Relations
# Financial Planning
# Computer Engineering Technology (CET)
# Corporate Finance
# Engineering Science
# European History
# Rhetoric
# Network Engineering
# Mechanical Design
# Environmental Engineering
# Chinese Language
# Robotics
# Economics & Management
# Computing
# Product Design
# Mechanical Engineering Technology (MET)
# Industrial & Labor Relations
# Food Science & Technology
# Accounting & Auditing
# Biochemistry (BCH)
# Accounting & Finance
# Agricultural Economics & Business
# Engineering Technology (ET)
# Biotechnology
# Dairy Science
# Operations Management (OM)
# Web Development
# Industrial Management
# Information Assurance
# Telecommunication & Information Management
# Environmental Policy Analysis & Planning
# Pharmaceutical Sciences (PS)
# Aviation
# Business & Marketing
# Computer Networking Systems
# Organizational Behavior
# Consumer Economics
# Information Technology (IT)
# Sales & Business Marketing
# Aviation Management
# Informatics
# Industrial Safety
# Structural Design & Construction Engineering Technology
# Computer Security
# Hotel Administration
# Software Applications & Programming
# Occupational Health and Safety
# Database Management
# Business Technology Management
# Production Management
# Business & Finance
# Environmental Health & Safety
# Information Technology (IT) & Systems
# Telecommunications Management
# Electronics Engineering Technology (EET)
# Marketing & Management
# Operations & Supply Chain Management
# Physical Therapy
# Politics
# Physics & Astronomy
# Agribusiness
# Chemistry
# Finance & Banking
# Aviation Flight Science (AFL)
# Construction Science & Management
# Marketing
# Cell Biology
# Civil Engineering Technology (CET)
# Genetics
# Government & Politics
# Biopsychology
# Applied Networking & Systems Administration
# Industrial Technology (IT)
# Geological Engineering
# Real Estate Development
# Accounts
# Electromechanical Engineering
# Risk Management
# Social Ecology
# Microbiology & Immunology
# French Literature
# City & Regional Planning
# Construction Technology
# Italian Language
# Marketing Communication
# Business Management & Marketing
# Industrial Design (ID)
# Marketing & Communications
# Political Science
# Advertising Design
# Manufacturing Management
# Computer Information Systems
# Network Security
# Risk Management & Insurance
# Comparative Literature
# Sales & Marketing
# Welding Engineering Technology
# Philosophy
# Networks & Telecommunications
# Business Data Analysis
# Environmental Science & Policy
# German Language
# Japanese Studies
# Atmospheric Science
# Business Psychology
# Digital Design
# International Development Studies
# Accounting
# Spanish Literature
# Technical Communication
# Computer Programming
# Architecture
# Project Management
# Hotel Management
# Music Production & Engineering
# Urban Planning
# Cell & Molecular Biology
# Safety Management
# Manufacturing Engineering Technology
# Advertising
# Marketing Management
# Insurance
# Occupational Therapy (OT)
# Applied Computer Science
# Geology
# Meteorology
# Electronic Systems Technology (EST)
# Environmental Design
# Radiation Therapy
# Latin American Studies
# Logistics
# Transportation & Logistics Management
# Applied Technology
# Environmental Health
# Design
# Computer Graphics Technology (CGT)
# Crop Science
# Industrial Psychology
# Entrepreneurship
# German Studies
# Neuroscience
# Computer & Network Administration
# Financial Accounting
# Food Science
# Microbiology
# Digital Media Design
# Agronomy
# Accounting & Management
# Aeronautics
# Business Communication
# Urban & Regional Planning
# Global Business Management
# Police Science
# Math & Science
# Corporate Communications
# Political Science/Public Law
# Accounting Information Systems
# Anthropology & English
# Organizational Psychology
# Advertising & Marketing Communications
# Entomology
# Product Design Engineering
# Personal Financial Planning
# Biological Sciences
# Pre-law
# Textile Technology
# Strategic Communication
# Technology
# Environmental Science
# International Studies
# Cinema Studies
# Professional & Technical Writing
# Automotive Technology
# New Media Design
# Theatre & Drama Studies
# Information Systems Security
# Aviation Maintenance Technology
# Organizational Development
# Financial Management
# International Trade & Business
# Textile & Apparel Studies
# Toxicology
# Construction Engineering Technology
# Advertising & Marketing
# English Literature
# Advertising & Promotion
# Agricultural Science
# Fashion Design
# Hydrology
# Technical Management
# Electronics & Computer Technology
# French Studies
# Magazine Journalism
# Management
# Sociology & Organizational Studies
# International Affairs
# Business Administration
# Finance & Marketing
# Land Surveying
# Journalism & Mass Communication
# Business Management
# Speech & Drama
# Agribusiness Management
# Digital Media
# Drama
# Linguistics
# Architectural Engineering Technology
# General Science
# Pre-Medicine
# Business Administration & Accounting
# History & Politics
# Nursing Science
# Global Business
# Integrated Marketing Communications
# American History (United States)
# Architectural Studies
# Communication
# Personnel Management
# General Business
# Interior Architecture
# Public Affairs
# Natural Sciences
# Writing
# Human Biology
# Marketing & Mass Communications
# Computer Art
# French Language
# Journalism
# Interpersonal & Organizational Communication
# Organizational Communication
# Textile Design
# Biology & Chemistry
# Nursing
# Public Relations & Communication
# Environmental & Natural Resource Economics
# Biology
# Environmental Management
# General & Strategic Management
# Bachelor in Science Nursing
# History
# Literature
# Law
# Physiology
# Entrepreneurial Studies
# Public Relations (PR)
# Retail Management
# Computer Aided Drafting & Design (CADD)
# Management & Organization
# Agriculture
# Music Technology
# Administration of Justice
# Publishing
# Urban Studies
# Media Studies
# Apparel & Textile Manufacture
# Philosophy & Religion
# Environmental Geography
# Communication Studies & Journalism
# Interpersonal Communications
# Logistics Management
# Retail & Consumer Science
# Web Design & Development
# Accounting & Business
# Architectural Technology
# Geographic Information Systems (GIS)
# Environmental Studies
# Interactive Media
# Retail Merchandising
# Diagnostic Medical Sonography
# Agricultural Business
# Network Administration
# Environmental Biology
# Dental Hygiene
# Journalism & Electronic Media
# Web & Digital Media Development
# Workforce Education & Development
# Diagnostic Medical Ultrasound
# Health Policy & Administration
# Quality Management
# Bachelor of Science in Nursing
# Speech Communication
# Retailing
# Visual Effects & Motion Graphics
# Foreign Languages
# Landscape Architecture
# Global Studies
# American Sign Language Interpreting
# Spanish Language Teacher Education
# Technical & Scientific Communication
# Broadcast & Cinematic Arts
# Computer Animation
# Geography
# Environmental Resource Management
# Fashion
# Film Studies
# Forestry
# Business Leadership
# Nursing Education
# English Language
# Ancient History
# Botany
# Geosciences
# Computer Aided Design (CAD)
# Digital Arts
# Leadership
# Automotive Technology & Service Management
# Business Management & Administration
# Business Management & Human Resources Management (HRM)
# Human Resources Management (HRM)
# Radio/Television & Film Production
# Allied Health
# English Language & Literature
# Marine Biology
# Security Management
# Organizational Leadership
# Public Administration
# Forestry Management
# Management (MGT)
# Merchandising Management
# Administrative Management
# Spanish Language
# Sports Management
# Arts Management
# Homeland Security
# Electronic Media
# 3D Animation
# Film Production
# Marine Science
# Information & Communication Technology
# Mass Communication
# Museum Studies
# Technical Writing
# Religious Studies
# Travel Industry Management
# Art History
# Fashion Merchandising
# Nuclear Medicine Technology
# Marketing & Advertising
# Musicology
# Broadcast Journalism
# Animation
# Historic Preservation
# Music Performance
# Organizational Leadership & Supervision
# Multimedia
# Business Technology
# Radiologic Science
# Human Nutrition
# Acting
# Liberal Arts
# Apparel Merchandising
# German Language & Literature
# Organizational Management
# Zoology
# Creative Writing
# Geomatics
# Law Enforcement
# Administration
# Cytotechnology
# Fashion Marketing & Management
# Applied Management
# Management & Leadership
# Human Resources (HR)
# Animal Science & Management
# Adult Education & Training
# Agricultural Communication
# Health & Fitness
# Criminal Justice Administration
# Emergency Management
# Media Arts
# Sociology & Anthropology
# Radiology
# Communication Design
# Earth Science
# Modern Languages
# Training and Development
# Hospital Administration
# Human Relations
# Natural Resources
# Ethnic Studies
# Hotel & Restaurant Management
# Broadcast Communication
# Mass Media
# Advertising & Graphic Design
# Radiologic Technology
# Merchandising
# Romance Languages
# Environmental Health Science
# Criminology
# Psychology
# Cardiopulmonary Science
# Labor Studies
# Medical Laboratory Technology
# Visual Communications
# Audio Engineering
# Middle Eastern Studies
# Health
# Hospitality Management
# Health Care Management
# Painting & Printmaking
# Multimedia & Web Design
# Health Administration
# Natural Resource Management
# Psychology & Social Behavior
# Communication Management
# Health Sciences
# Nutrition Science
# Web Design
# Health Management
# Life Sciences
# Anthropology
# Music
# Ecology
# Human Resources Development
# SocialStudies
# New Media
# Psychiatry
# Sociology
# Health Care Administration
# Interior Design
# Respiratory Care
# Health Information Management
# Art & Design
# Child Psychology
# Clinical Laboratory Science
# Diagnostic Medical Imaging
# Humanities
# Medical Laboratory Science
# Theater
# Kinesiology
# Exercise Physiology
# Forensic Accounting
# Secondary Education
# Multidisciplinary Studies
# Archaeology
# Communication Arts
# Arts & Science
# Illustration
# Sustainability
# Hotel & Restaurant Tourism
# Radiography
# Media Communication
# Respiratory Therapy
# Applied Behavior Analysis
# Technology Teacher Education
# Professional Studies
# Communications Technology
# Biological Anthropology
# Art Therapy
# Commercial Photography
# Liberal Studies
# Radio & Television
# Nutrition
# Plant Sciences
# Graphic Design
# Legal Studies
# Nutrition & Dietetics
# Turfgrass Management
# Dietetics
# Interdisciplinary Studies (IS)
# Fashion Design & Marketing
# Applied Sociology
# Hospital Management
# Religion
# Medical Technology
# Art Administration
# Criminal Justice
# Fine Arts
# Criminal Law
# Forensic Science
# Philosophy & Religious Studies
# Public Health (PH)
# Speech-Language Pathology
# Landscape Management
# Women's Studies
# Forensic Psychology
# Modern Language Spanish
# Educational Studies (ED)
# Physical Geography
# Culture Studies
# Pastoral Studies
# Dramatic Art
# Music Industry
# Performing Arts
# African American & African Studies
# Animal Science
# Ornamental Horticulture
# Hospitality & Tourism
# Education
# Foods & Nutrition
# Fashion & Retail Management
# Music Composition
# Small Business Management
# Clinical Nutrition
# Painting
# Speech Pathology & Audiology
# Psychology & Sociology
# Physical Education Teaching
# Clinical Psychology
# Health Studies
# Instrumental Music Teacher Education
# Technical Theatre
# Art
# Social & Criminal Justice
# Consumer Affairs
# Family & Consumer Science
# Network Technology
# Photography
# Video Production
# International Trade
# Horticulture & Agronomy
# Missions
# General Studies
# Health Services Administration
# Justice Studies
# Culinary Arts
# Physical Therapist Assistant Studies
# English Teacher Education
# Exercise & Sports Science
# Health & Exercise Science
# Recreation & Leisure Studies
# Sports Administration
# Graphic Arts
# Supervision & Management
# Secondary English Teacher Education
# Exercise Science
# Interior Design & Merchandising
# Health & Wellness
# Restaurant & Food Service Management
# Behavioral Science
# Culinary Arts & Food Service Management
# Event Management
# Theology
# Wildlife Management
# Health & Physical Education Teaching
# Ministry
# Mortuary Science
# Media Production
# Communicative Disorders
# Health Services Management
# Paralegal Studies
# Social Science Teacher Education
# Recreation Administration
# Rehabilitation Counseling
# Audio Production
# Radio Broadcasting
# Community Health
# Drawing
# Dance
# Music Teacher Education
# Gender Studies
# Photojournalism
# Family & Community Services
# Conservation Biology
# Drawing & Painting
# Organizational Administration
# Vocal Performance
# Clinical Social Work (CSW)
# Tourism & Travel
# Tourism Management
# Wildlife Biology
# Teaching English as a Second Language (ESL)
# Parks & Recreation Management
# Social Services
# Elementary Special Education
# Ceramics
# Horticulture
# Landscape Design
# Rehabilitation Services
# Speech & Hearing
# Sculpture
# Health Promotion
# Athletic Training
# Family Studies
# History Teacher Education
# Social Studies Teacher Education
# Biblical Studies & Practical Ministries
# Communication Sciences & Disorders
# Emergency Medical Services (EMS)
# Deaf Studies
# Community Health Education
# Musical Theatre
# Pastoral Ministry
# Bible Studies & Theology
# Biblical Studies
# Christian Ministry
# Human Development & Family Studies
# Church Ministries
# Community Development
# Music Therapy
# Voice & Opera
# Legal Assistant Studies
# Health and Human Services
# Home Economics
# Special Education
# Conflict Resolution
# Educational Psychology
# Developmental Psychology
# Youth Ministry
# Therapeutic Recreation
# Community & Human Services
# Social Work (SW)
# Elementary Education
# Office Administration
# Christian Education
# Counseling
# Human Services (HS)
# Health & Human Performance
# Mental Health Counseling
# Middle School Education
# Child Development
# Recreational Therapy
# Early Childhood & Elementary Education
# Outdoor Education
# Baking & Pastry Arts
# Mental Health
# Child & Family Studies
# Equine Studies
# Addictions Counseling
# Nonprofit Administration
# Early Childhood Education
# Metalsmithing

# %%
#major with highest mid-career salary:

#if thyere were duplicates then try: df_current.groupby('major').apply(lambda x:x.loc[:,"midCareerMedianPay"]).idxmax()

df_current.sort_values(by="midCareerMedianPay",ascending=False).head()

##petroleum engineering is the major with highest midCareerMedium Pay
# Out:
#      id degreeType                                         major  \
# 0  5088  Bachelors                         Petroleum Engineering
# 1  5614  Bachelors  Operations Research & Industrial Engineering
# 2  5615  Bachelors                            Interaction Design
# 3  5616  Bachelors              Applied Economics and Management
# 4  5617  Bachelors                              Building Science
#
#    earlyCareerMedianPay  midCareerMedianPay  fiveToTenYearMedianPay  \
# 0                 97500              212500              151,800.00
# 1                 98300              191800              153,700.00
# 2                 74700              173600              118,400.00
# 3                 76500              164400              112,800.00
# 4                 69000              163100               99,100.00
#
#    tenToTwentyYearMedianPay  twentyPlusYearMedianPay  percentHighMeaning  \
# 0                197,600.00               226,100.00                0.61
# 1                188,500.00                      NaN                0.21
# 2                173,600.00                      NaN                0.54
# 3                164,400.00                      NaN                0.54
# 4                152,600.00               179,000.00                0.47
#
#    year                                                url  rank    tie  \
# 0  2023  /research/US/Degree=Bachelor%27s_Degree%2C_Pet...     1  False
# 1  2023  /research/US/Degree=Bachelor%27s_Degree%2C_Ope...     2  False
# 2  2023  /research/US/Degree=Bachelor%27s_Degree%2C_Int...     3  False
# 3  2023  /research/US/Degree=Bachelor%27s_Degree%2C_App...     4  False
# 4  2023  /research/US/Degree=Bachelor%27s_Degree%2C_Bui...     5  False
#
#      spread
# 0 54,300.00
# 1 55,400.00
# 2 43,700.00
# 3 36,300.00
# 4 30,100.00

# %%
#major with lowest mid-career salary:

# This is another way to do it if duplicates available: df_current.groupby('major').apply(lambda x:x.loc[:,"midCareerMedianPay"]).idxmin()

df_current.sort_values(by="midCareerMedianPay",ascending=True).head()

## Metalsmithing is the major with lowest midCareerMedium Pay
# Out:
#        id degreeType                      major  earlyCareerMedianPay  \
# 798  5886  Bachelors              Metalsmithing                 44700
# 797  5486  Bachelors  Early Childhood Education                 41700
# 796  5359  Bachelors   Nonprofit Administration                 42800
# 795  5358  Bachelors      Addictions Counseling                 45900
# 794  5357  Bachelors             Equine Studies                 40300
#
#      midCareerMedianPay  fiveToTenYearMedianPay  tenToTwentyYearMedianPay  \
# 798               44900               57,400.00                       NaN
# 797               50600               44,300.00                 48,800.00
# 796               52100               54,500.00                       NaN
# 795               52200                     NaN                 50,300.00
# 794               52500                     NaN                 51,900.00
#
#      twentyPlusYearMedianPay  percentHighMeaning  year  \
# 798                      NaN                0.36  2023
# 797                54,200.00                0.77  2023
# 796                      NaN                0.72  2023
# 795                      NaN                0.78  2023
# 794                      NaN                0.50  2023
#
#                                                    url  rank    tie    spread
# 798  /research/US/Degree=Bachelor%27s_Degree%2C_Met...   799  False 12,700.00
# 797  /research/US/Degree=Bachelor%27s_Degree%2C_Ear...   798  False  2,600.00
# 796  /research/US/Degree=Bachelor%27s_Degree%2C_Non...   797  False 11,700.00
# 795  /research/US/Degree=Bachelor%27s_Degree%2C_Add...   796  False       NaN
# 794  /research/US/Degree=Bachelor%27s_Degree%2C_Equ...   795  False       NaN

# %%
#Major with lowest starting salary:

## another way if duplicates available: df_current.groupby('major').apply(lambda x:x.loc[:,"earlyCareerMedianPay"]).idxmin()

df_current.sort_values(by="earlyCareerMedianPay", ascending=True).head()

#lowest starting salary major is Voice $ Opera
# Out:
#        id degreeType                     major  earlyCareerMedianPay  \
# 767  5380  Bachelors             Voice & Opera                 38700
# 576  5139  Bachelors    Painting & Printmaking                 39300
# 794  5357  Bachelors            Equine Studies                 40300
# 785  5348  Bachelors  Mental Health Counseling                 40600
# 745  5308  Bachelors   Rehabilitation Services                 41300
#
#      midCareerMedianPay  fiveToTenYearMedianPay  tenToTwentyYearMedianPay  \
# 767               63200               56,600.00                 71,500.00
# 576               82600               45,200.00                 82,600.00
# 794               52500                     NaN                 51,900.00
# 785               58500               54,800.00                       NaN
# 745               67600               48,600.00                 57,600.00
#
#      twentyPlusYearMedianPay  percentHighMeaning  year  \
# 767                      NaN                0.53  2023
# 576                      NaN                0.46  2023
# 794                      NaN                0.50  2023
# 785                      NaN                 NaN  2023
# 745                71,200.00                0.74  2023
#
#                                                    url  rank    tie    spread
# 767  /research/US/Degree=Bachelor%27s_Degree%2C_Voi...   768  False 17,900.00
# 576  /research/US/Degree=Bachelor%27s_Degree%2C_Pai...   575   True  5,900.00
# 794  /research/US/Degree=Bachelor%27s_Degree%2C_Equ...   795  False       NaN
# 785  /research/US/Degree=Bachelor%27s_Degree%2C_Men...   786   True 14,200.00
# 745  /research/US/Degree=Bachelor%27s_Degree%2C_Reh...   746   True  7,300.00

# %%
#major with the lowest spread in the differnce in the pay between the early career median pay and the five to ten year median pay:

# %%
df_current['spread']=df_current.loc[:,'fiveToTenYearMedianPay'] - df_current.loc[:,'earlyCareerMedianPay']

# %%
df_current.groupby(by='major').apply(lambda x:x.loc[:,'spread']).idxmax()
df_current.sort_values(by='spread', ascending=False).head()

#Pharmacy has the highest differnce in the pay between early career median pay and the five to ten year median pay
# Out:
#        id degreeType                                         major  \
# 12   5625  Bachelors                                      Pharmacy
# 243  5806  Bachelors                                  Cell Biology
# 9    5622  Bachelors                Information & Computer Science
# 1    5614  Bachelors  Operations Research & Industrial Engineering
# 0    5088  Bachelors                         Petroleum Engineering
#
#      earlyCareerMedianPay  midCareerMedianPay  fiveToTenYearMedianPay  \
# 12                  69400              154000              130,100.00
# 243                 56800              108100              114,800.00
# 9                   76000              157800              131,700.00
# 1                   98300              191800              153,700.00
# 0                   97500              212500              151,800.00
#
#      tenToTwentyYearMedianPay  twentyPlusYearMedianPay  percentHighMeaning  \
# 12                 153,800.00               154,300.00                0.79
# 243                       NaN                      NaN                0.55
# 9                  146,700.00               171,200.00                0.63
# 1                  188,500.00                      NaN                0.21
# 0                  197,600.00               226,100.00                0.61
#
#      year                                                url  rank    tie  \
# 12   2023  /research/US/Degree=Bachelor%27s_Degree%2C_Pha...    13  False
# 243  2023  /research/US/Degree=Bachelor%27s_Degree%2C_Cel...   244   True
# 9    2023  /research/US/Degree=Bachelor%27s_Degree%2C_Inf...    10  False
# 1    2023  /research/US/Degree=Bachelor%27s_Degree%2C_Ope...     2  False
# 0    2023  /research/US/Degree=Bachelor%27s_Degree%2C_Pet...     1  False
#
#        spread
# 12  60,700.00
# 243 58,000.00
# 9   55,700.00
# 1   55,400.00
# 0   54,300.00

# %%
#Pharmacy has the highest spread in the median salary pay after five to ten years.
df_current.loc[12,'spread']
# Out:
# 60700.0

# %%
df_current.groupby(by='major').apply(lambda x:x.loc[:,'spread']).idxmin()
df_current.sort_values(by='spread', ascending=True).head()

#Personnel management has the highest differnce in the pay between early career median pay and after five to ten year median pay
# Out:
#        id degreeType                         major  earlyCareerMedianPay  \
# 394  5757  Bachelors          Personnel Management                 57900
# 719  5332  Bachelors     Recreation Administration                 54200
# 766  5379  Bachelors                 Music Therapy                 48500
# 741  5304  Bachelors  Elementary Special Education                 51200
# 663  5476  Bachelors       Ornamental Horticulture                 51600
#
#      midCareerMedianPay  fiveToTenYearMedianPay  tenToTwentyYearMedianPay  \
# 394               94800               58,100.00                 80,900.00
# 719               70600               54,500.00                 69,900.00
# 766               63500               49,500.00                 61,900.00
# 741               68300               53,100.00                 61,900.00
# 663               76000               53,700.00                 69,100.00
#
#      twentyPlusYearMedianPay  percentHighMeaning  year  \
# 394               104,500.00                0.68  2023
# 719                72,800.00                0.66  2023
# 766                64,100.00                0.95  2023
# 741                      NaN                0.81  2023
# 663                86,600.00                0.67  2023
#
#                                                    url  rank    tie   spread
# 394  /research/US/Degree=Bachelor%27s_Degree%2C_Per...   393   True   200.00
# 719  /research/US/Degree=Bachelor%27s_Degree%2C_Rec...   720   True   300.00
# 766  /research/US/Degree=Bachelor%27s_Degree%2C_Mus...   767  False 1,000.00
# 741  /research/US/Degree=Bachelor%27s_Degree%2C_Ele...   742  False 1,900.00
# 663  /research/US/Degree=Bachelor%27s_Degree%2C_Orn...   663   True 2,100.00

# %%
df_current.loc[19,'spread']   # Personnel accounting has the minimum spread of median salary pay after 5 to 10 years
# Out:
# 7900.0
